# %%
import pandas as pd

#docs = pd.read_excel('SMSSpamCollection.xls',header=None,names=['Class', 'SMS']) 
docs = pd.read_table('C:/Users/chaganti.babu/Documents/ML&AI/ML/Naive Bayes/Assignment/example_train.csv', header=None, names=['Class', 'sms'])

#classifier in column 1, sms in column 2.
docs.head()
# Out:
#                                                Class  sms
# 0                                     Document,Class  NaN
# 1  Upgrad is a great educational institution.,edu...  NaN
# 2  Educational greatness depends on ethics,education  NaN
# 3  A story of great ethics and educational greatn...  NaN
# 4                    Sholey is a great cinema,cinema  NaN

# %%
# counting spam and ham instances
# df.column_name.value_counts() - gives no. of unique inputs in the columns

ham_spam=docs.Class.value_counts()
ham_spam
# Out:
# ham     4825
# spam     747
# Name: Class, dtype: int64

# %%
print("Spam % is ",(ham_spam[1]/float(ham_spam[0]+ham_spam[1]))*100)
# Out:
# Spam % is  13.406317300789663

# %%
# mapping labels to 0 and 1
docs['label'] = docs.Class.map({'ham':0, 'spam':1})

# %%
docs.head()
# Out:
#   Class                                                sms  label
# 0   ham  Go until jurong point, crazy.. Available only ...      0
# 1   ham                      Ok lar... Joking wif u oni...      0
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...      1
# 3   ham  U dun say so early hor... U c already then say...      0
# 4   ham  Nah I don't think he goes to usf, he lives aro...      0

# %%
X=docs.sms
y=docs.label

# %%
X = docs.sms
y = docs.label
print(X.shape)
print(y.shape)
# Out:
# (5572,)
# (5572,)

# %%
# splitting into test and train into default 75:25 ratio

from sklearn.model_selection  import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.head()
# Out:
# 710     4mths half price Orange line rental & latest c...
# 3740                           Did you stitch his trouser
# 2711    Hope you enjoyed your new content. text stop t...
# 3155    Not heard from U4 a while. Call 4 rude chat pr...
# 3748    Ü neva tell me how i noe... I'm not at home in...
# Name: sms, dtype: object

# %%
X_train.shape
# Out:
# (4179,)

# %%
X_test.shape
# Out:
# (1393,)

# %%
# vectorizing the sentences; removing stop words
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer(stop_words='english')

# %%
vect.fit(X_train)
# X_train_dtm = vect.transform(X_train)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words='english',
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# printing the vocabulary
vect.vocabulary_
# Out:
# {'problem': 5047,
#  'gower': 2997,
#  'cal': 1502,
#  'some1': 5848,
#  'opinions': 4614,
#  'trusting': 6554,
#  'playing': 4878,
#  'fgkslpo': 2637,
#  'weigh': 6924,
#  'gumby': 3063,
#  '〨ud': 7203,
#  'library': 3824,
#  'teaches': 6272,
#  'charles': 1636,
#  'munsters': 4343,
#  'letter': 3817,
#  'sportsx': 5956,
#  'entitled': 2446,
#  'wicklow': 6974,
#  'soiree': 5841,
#  '1hr': 318,
#  'hanks': 3109,
#  'goin': 2958,
#  '2mrw': 395,
#  'quote': 5154,
#  'slowly': 5793,
#  'working': 7062,
#  'king': 3684,
#  'hyde': 3329,
#  'john': 3584,
#  'catch': 1583,
#  'asjesus': 1031,
#  'usually': 6712,
#  'thekingshead': 6352,
#  'glad': 2936,
#  'tram': 6514,
#  'box245c2150pm': 1364,
#  'akon': 864,
#  'wasted': 6874,
#  'cheers': 1662,
#  'ques': 5141,
#  'prix': 5041,
#  '26': 363,
#  'stairs': 5978,
#  'notxt': 4514,
#  'infra': 3429,
#  'ideas': 3353,
#  'frying': 2819,
#  'sk38xh': 5757,
#  'heehee': 3171,
#  'hi': 3202,
#  'ericsson': 2459,
#  '4msgs': 508,
#  'wait': 6834,
#  'revision': 5372,
#  'sherawat': 5652,
#  '5ish': 544,
#  'felt': 2628,
#  'street': 6056,
#  'jet': 3569,
#  'instantly': 3452,
#  '1tulsi': 328,
#  'laundry': 3770,
#  'fetch': 2631,
#  'lady': 3732,
#  'allday': 882,
#  'shah': 5629,
#  'ipad': 3485,
#  'ignoring': 3363,
#  '09061743806': 189,
#  'hadn': 3079,
#  'web': 6905,
#  'wks': 7026,
#  'cried': 1959,
#  'missionary': 4218,
#  'play': 4873,
#  'image': 3374,
#  'msgrcvdhg': 4319,
#  'goto': 2991,
#  'picked': 4834,
#  'bfore': 1250,
#  'await': 1097,
#  'rebel': 5229,
#  'words': 7057,
#  'history': 3215,
#  '14thmarch': 289,
#  'guessing': 3057,
#  'moby': 4254,
#  'orno': 4640,
#  'remove': 5305,
#  'cstore': 1975,
#  'bluetooth': 1316,
#  'nange': 4379,
#  'chad': 1615,
#  'pray': 4992,
#  'wocay': 7035,
#  'code': 1770,
#  'asshole': 1042,
#  'possession': 4947,
#  'tank': 6245,
#  'optout': 4623,
#  'noi': 4478,
#  'largest': 3755,
#  'improved': 3395,
#  'woul': 7079,
#  'plaza': 4880,
#  'arr': 1011,
#  'link': 3858,
#  'lautech': 3772,
#  'ard': 990,
#  'reply': 5321,
#  'treated': 6530,
#  'desires': 2135,
#  'grahmbell': 3005,
#  'gyno': 3074,
#  'das': 2043,
#  'morning': 4289,
#  'prompts': 5074,
#  'sponsors': 5949,
#  'truble': 6546,
#  'manege': 4062,
#  'bitching': 1279,
#  'studdying': 6076,
#  'ths': 6397,
#  'ic': 3342,
#  'wheel': 6957,
#  'solihull': 5845,
#  'calculated': 1503,
#  'inshah': 3446,
#  'bbc': 1176,
#  'visit': 6789,
#  'pop': 4933,
#  'constantly': 1862,
#  '2waxsto': 406,
#  'mango': 4063,
#  'liked': 3841,
#  'hide': 3204,
#  'hamster': 3097,
#  'exhaust': 2522,
#  'manageable': 4054,
#  'age16': 832,
#  'bro': 1421,
#  'bognor': 1327,
#  'knows': 3703,
#  '3mins': 451,
#  'roads': 5400,
#  'vomit': 6802,
#  'lover': 3958,
#  'germany': 2906,
#  'ugo': 6611,
#  'record': 5251,
#  'flies': 2698,
#  'oxygen': 4678,
#  'bell': 1223,
#  'hw': 3328,
#  'xin': 7120,
#  'escape': 2471,
#  'entry': 2449,
#  'weeks': 6923,
#  'opinion': 4613,
#  'qi': 5132,
#  'bullshit': 1462,
#  'womdarfull': 7039,
#  'pushes': 5122,
#  'computerless': 1831,
#  'local': 3896,
#  'illspeak': 3371,
#  '09061104276': 178,
#  'kept': 3656,
#  'wadebridge': 6827,
#  'sneham': 5827,
#  'inever': 3420,
#  'pink': 4851,
#  'converted': 1877,
#  'b4utele': 1116,
#  'fixedline': 2685,
#  'willing': 6985,
#  '25': 358,
#  'knickers': 3698,
#  'sunshine': 6148,
#  'oga': 4571,
#  'premium': 5002,
#  'prone': 5075,
#  'fifa': 2643,
#  'helpful': 3183,
#  '08718726978': 136,
#  'priya': 5042,
#  'ironing': 3495,
#  'sp': 5898,
#  'fal': 2574,
#  'answered': 929,
#  'effect': 2390,
#  'students': 6079,
#  'calls1': 1522,
#  'lov': 3951,
#  'dub': 2333,
#  'curfew': 1994,
#  'wonder': 7044,
#  'really': 5219,
#  'sake': 5476,
#  'punish': 5109,
#  'ctter': 1980,
#  'romcapspam': 5416,
#  'story': 6050,
#  'blacko': 1286,
#  'bstfrnd': 1442,
#  'gender': 2892,
#  'wa': 6823,
#  'desperate': 2139,
#  'phb1': 4811,
#  'card': 1547,
#  'require': 5328,
#  'gr8': 3000,
#  'area': 991,
#  'ammae': 900,
#  'tis': 6431,
#  'tom': 6463,
#  'manual': 4066,
#  'echo': 2375,
#  'l8': 3718,
#  'gone': 2968,
#  'suffer': 6123,
#  'eyes': 2555,
#  '0825': 60,
#  'cold': 1777,
#  'attracts': 1069,
#  'nigeria': 4458,
#  'arty': 1021,
#  'rec': 5233,
#  'reservations': 5334,
#  'euro': 2481,
#  'kiss': 3689,
#  'style': 6090,
#  'kickoff': 3669,
#  'cake': 1501,
#  'mobsi': 4253,
#  'naseeb': 4384,
#  'floor': 2708,
#  'c52': 1496,
#  'terms': 6307,
#  '3750': 437,
#  'announcement': 922,
#  't4get2text': 6212,
#  'belt': 1230,
#  'caps': 1543,
#  'sppok': 5959,
#  'notebook': 4506,
#  'nvm': 4535,
#  'tensed': 6303,
#  'dead': 2061,
#  'hav2hear': 3139,
#  'alwys': 891,
#  'hr': 3294,
#  'teletext': 6288,
#  'kind': 3681,
#  'wahleykkum': 6832,
#  '32000': 428,
#  'camera': 1527,
#  'tomarrow': 6464,
#  'natalie': 4388,
#  'tea': 6269,
#  'nannys': 4380,
#  'saucy': 5508,
#  'hockey': 3233,
#  'ringtone': 5389,
#  'yeh': 7153,
#  'coco': 1769,
#  'hiya': 3220,
#  'preferably': 4999,
#  'remembr': 5297,
#  'wipro': 7002,
#  '26th': 365,
#  'clean': 1728,
#  '3d': 443,
#  'bein': 1220,
#  'flaky': 2690,
#  'collected': 1783,
#  '7cfca1a': 611,
#  'relaxing': 5287,
#  'deepak': 2087,
#  'step': 6014,
#  'certificate': 1612,
#  'man': 4052,
#  'useful': 6703,
#  'ideal': 3352,
#  'reapply': 5222,
#  'reached': 5203,
#  'tape': 6248,
#  'shijas': 5657,
#  'doggin': 2252,
#  'forward': 2761,
#  'nick': 4455,
#  'summer': 6139,
#  'ignore': 3362,
#  'aldrine': 869,
#  'adult': 806,
#  'tree': 6533,
#  'worth': 7074,
#  'wasting': 6875,
#  '165': 303,
#  'balloon': 1141,
#  '09066358152': 216,
#  '09058094599': 175,
#  'bet': 1239,
#  'babysitting': 1125,
#  'copy': 1893,
#  'rebtel': 5232,
#  'paragon': 4711,
#  'aroundn': 1010,
#  'lambda': 3737,
#  'tirunelvai': 6428,
#  'strewn': 6060,
#  'linear': 3853,
#  'overtime': 4670,
#  'kisses': 3690,
#  'vomiting': 6804,
#  'childish': 1681,
#  'threats': 6389,
#  'means': 4120,
#  'al': 865,
#  'year': 7150,
#  'solved': 5847,
#  'wall': 6845,
#  'receive': 5237,
#  'accomodate': 756,
#  'pc': 4760,
#  '861': 662,
#  'prizeawaiting': 5044,
#  'heart': 3162,
#  'or2stoptxt': 4624,
#  'language': 3747,
#  'jog': 3582,
#  'buen': 1453,
#  '84199': 653,
#  'cared': 1553,
#  'dobby': 2238,
#  'kitty': 3692,
#  '12hrs': 276,
#  'guys': 3068,
#  'saristar': 5499,
#  'disaster': 2207,
#  '630': 565,
#  'yoga': 7168,
#  'del': 2099,
#  'intrepid': 3469,
#  'jerk': 3564,
#  'hudgi': 3301,
#  'shakespeare': 5633,
#  'gsex': 3042,
#  'hopefully': 3262,
#  'pictures': 4840,
#  '48922': 497,
#  'catches': 1584,
#  'mobileupd8': 4250,
#  'day': 2054,
#  'proper': 5078,
#  'sweater': 6189,
#  'shortcode': 5686,
#  'turning': 6579,
#  'ans': 926,
#  'thnx': 6380,
#  'bahamas': 1134,
#  'brum': 1437,
#  'nte': 4521,
#  '255': 361,
#  '2morro': 391,
#  'fastest': 2599,
#  'potential': 4961,
#  'snuggles': 5834,
#  'dan': 2025,
#  'accent': 747,
#  'shampain': 5637,
#  '3xx': 461,
#  'stay': 6001,
#  'tip': 6424,
#  '21870000': 346,
#  'weakness': 6897,
#  '69911': 582,
#  'oh': 4573,
#  'weekend': 6920,
#  'calld': 1512,
#  'madam': 4024,
#  'gnt': 2947,
#  'hungry': 3314,
#  '69101': 574,
#  '2morow': 390,
#  'uncles': 6627,
#  'hey': 3198,
#  'car': 1546,
#  'afraid': 823,
#  'wont': 7048,
#  'vewy': 6757,
#  'september': 5604,
#  'milk': 4182,
#  'digi': 2184,
#  'anna': 918,
#  'tenerife': 6302,
#  'heading': 3152,
#  'syd': 6205,
#  'msg': 4315,
#  'needing': 4415,
#  'come': 1794,
#  'cliff': 1737,
#  'specify': 5916,
#  'bcaz': 1181,
#  'purchases': 5115,
#  'varunnathu': 6737,
#  'reward': 5373,
#  '1500': 292,
#  'invited': 3478,
#  'wishing': 7010,
#  'andre': 912,
#  'drunkard': 2327,
#  'rite': 5396,
#  'yes': 7160,
#  'virtual': 6786,
#  'infront': 3430,
#  'tmrw': 6444,
#  'slip': 5784,
#  'diapers': 2164,
#  'wiskey': 7012,
#  'wknd': 7025,
#  'aww': 1105,
#  'gbp1': 2882,
#  'forgot': 2750,
#  'ranjith': 5185,
#  'blessing': 1297,
#  'hearts': 3164,
#  'freak': 2776,
#  'woodland': 7050,
#  'lucky': 3980,
#  'evenings': 2489,
#  'email': 2412,
#  'dollar': 2261,
#  '220cm2': 350,
#  '402': 466,
#  'child': 1680,
#  'prashanthettan': 4990,
#  'boyf': 1379,
#  'nokia6650': 4485,
#  'dollars': 2262,
#  'ipod': 3489,
#  'legal': 3799,
#  'outdoors': 4654,
#  'centre': 1608,
#  'drinkin': 2310,
#  'nos': 4503,
#  'cashbin': 1574,
#  'goodnoon': 2980,
#  'replied': 5319,
#  'monthly': 4280,
#  'triple': 6539,
#  'si': 5713,
#  'shore': 5682,
#  'easily': 2364,
#  'matter': 4102,
#  'dat': 2044,
#  'sick': 5716,
#  'rocking': 5405,
#  'txt250': 6591,
#  'hmmm': 3226,
#  'furniture': 2840,
#  'xx': 7125,
#  'voice': 6799,
#  'problematic': 5048,
#  'extract': 2552,
#  's89': 5464,
#  'slightly': 5783,
#  '88800': 680,
#  'wed': 6910,
#  'stop': 6038,
#  'england': 2433,
#  'yam': 7139,
#  'sources': 5893,
#  'stereo': 6016,
#  '29': 372,
#  'hehe': 3172,
#  'gold': 2961,
#  'nuther': 4532,
#  'frmcloud': 2808,
#  'lasagna': 3757,
#  'dokey': 2260,
#  'abta': 743,
#  'secret': 5560,
#  'acted': 771,
#  'hella': 3177,
#  'everybody': 2492,
#  'yaxxx': 7146,
#  'service': 5608,
#  'function': 2832,
#  'lambu': 3738,
#  'merry': 4160,
#  '09058094597': 174,
#  'companies': 1810,
#  'machi': 4016,
#  'trust': 6553,
#  '09064019788': 207,
#  'lar': 3751,
#  'butt': 1480,
#  'class': 1724,
#  'reduce': 5259,
#  'awesome': 1103,
#  'brother': 1429,
#  'marriage': 4081,
#  'danger': 2031,
#  'wrkin': 7091,
#  'decimal': 2078,
#  'bank': 1146,
#  'jen': 3559,
#  'gayle': 2878,
#  'mas': 4087,
#  'splleing': 5944,
#  'saying': 5517,
#  'kills': 3679,
#  'november': 4517,
#  'losers': 3935,
#  'auction': 1071,
#  'water': 6882,
#  'hearted': 3163,
#  '1mega': 321,
#  'cc': 1593,
#  '4403ldnw1a7rw18': 480,
#  'rofl': 5409,
#  'sit': 5747,
#  'dai': 2021,
#  'vip': 6782,
#  'checked': 1655,
#  'amp': 903,
#  'bulbs': 1460,
#  'gaytextbuddy': 2880,
#  'bag': 1132,
#  'rub': 5442,
#  '09065069154': 209,
#  'elvis': 2410,
#  'thankyou': 6341,
#  'school': 5527,
#  'past': 4739,
#  'sent': 5598,
#  'listen': 3870,
#  'arul': 1022,
#  'passable': 4732,
#  'academic': 745,
#  'collecting': 1784,
#  '2007': 341,
#  'sonathaya': 5861,
#  'cud': 1983,
#  'second': 5557,
#  'stopsms': 6045,
#  'sumfing': 6138,
#  'baby': 1121,
#  'sliding': 5782,
#  'networks': 4437,
#  'pa': 4681,
#  'ag': 830,
#  'lemme': 3805,
#  'pee': 4767,
#  'sucker': 6117,
#  'care': 1551,
#  'pussy': 5123,
#  'tops': 6488,
#  'urfeeling': 6687,
#  'idew': 3356,
#  'callers': 1515,
#  'bite': 1280,
#  'looking': 3924,
#  'prakasamanu': 4986,
#  'cutefrnd': 2007,
#  'mistake': 4222,
#  'imat': 3377,
#  'hee': 3170,
#  'speaking': 5909,
#  'childporn': 1682,
#  'wonders': 7047,
#  'power': 4969,
#  'end': 2422,
#  'ertini': 2466,
#  'yay': 7147,
#  'foned': 2727,
#  'busetop': 1476,
#  'realized': 5217,
#  'http': 3298,
#  'max10mins': 4107,
#  'uploaded': 6679,
#  'kid': 3671,
#  'bani': 1145,
#  '08712405020': 106,
#  'contented': 1868,
#  'scraped': 5539,
#  'vary': 6738,
#  'weekends': 6921,
#  '69698': 577,
#  'fight': 2645,
#  'discussed': 2215,
#  'messaged': 4164,
#  'birla': 1271,
#  'hhahhaahahah': 3201,
#  'painting': 4692,
#  'flippin': 2703,
#  'witout': 7017,
#  'woozles': 7054,
#  'wisdom': 7004,
#  'alot': 886,
#  '050703': 17,
#  'screwd': 5546,
#  'send': 5590,
#  'maturity': 4105,
#  'afghanistan': 822,
#  'snap': 5823,
#  'transcribing': 6516,
#  'sections': 5566,
#  'spiral': 5934,
#  'hav': 3138,
#  'mad': 4021,
#  'coz': 1927,
#  'eldest': 2406,
#  'sunroof': 6147,
#  'bak': 1136,
#  'lines': 3856,
#  'racing': 5158,
#  'clos1': 1740,
#  'audition': 1072,
#  'crckt': 1946,
#  'deliveredtomorrow': 2108,
#  'en': 2421,
#  'sells': 5586,
#  'sky': 5766,
#  'amt': 907,
#  'bthere': 1444,
#  'yetunde': 7163,
#  'forced': 2740,
#  'gives': 2934,
#  'ps': 5093,
#  'wondar': 7042,
#  'x49': 7114,
#  'subtoitles': 6113,
#  'fund': 2834,
#  'blowing': 1312,
#  'railway': 5164,
#  'dogg': 2251,
#  'gving': 3070,
#  'secrets': 5563,
#  'tv': 6582,
#  '08718726970': 134,
#  'beauty': 1197,
#  '09064017295': 204,
#  'canlove': 1536,
#  'asking': 1036,
#  'synced': 6208,
#  'teasing': 6278,
#  'margin': 4074,
#  'isaiah': 3501,
#  'asssssholeeee': 1045,
#  'parchi': 4714,
#  '6months': 588,
#  'studyn': 6084,
#  'way': 6891,
#  'thread': 6388,
#  'new': 4442,
#  'weed': 6917,
#  'sports': 5955,
#  'se': 5550,
#  'jontin': 3596,
#  'tomeandsaid': 6466,
#  'get4an18th': 2907,
#  'm8s': 4007,
#  'net': 4429,
#  'dirt': 2200,
#  'figuring': 2651,
#  'complaining': 1817,
#  'version': 6754,
#  'dontcha': 2270,
#  'bros': 1426,
#  'upgrading': 6676,
#  'lessons': 3814,
#  'ipaditan': 3486,
#  'real': 5210,
#  'trash': 6522,
#  'annoying': 924,
#  '07090298926': 23,
#  'avin': 1093,
#  'arises': 1004,
#  'sarasota': 5496,
#  'conference': 1840,
#  '139': 281,
#  'seeing': 5571,
#  'raksha': 5174,
#  'walk': 6841,
#  'following': 2723,
#  'shudvetold': 5708,
#  'tp': 6505,
#  'website': 6909,
#  'cutting': 2010,
#  'gay': 2877,
#  'crucify': 1966,
#  '87121': 670,
#  'hamper': 3096,
#  'loses': 3936,
#  'bleak': 1294,
#  'stomps': 6034,
#  'windows': 6991,
#  'hidden': 3203,
#  'workin': 7061,
#  'venugopal': 6750,
#  'avoid': 1095,
#  '0808': 57,
#  'shakara': 5631,
#  'browser': 1434,
#  '08707509020': 85,
#  'tour': 6503,
#  'avent': 1091,
#  'disasters': 2208,
#  'la': 3722,
#  'plural': 4892,
#  'education': 2384,
#  'argue': 998,
#  '200': 335,
#  'guide': 3059,
#  'agents': 836,
#  '22': 348,
#  'wer': 6942,
#  'visitor': 6790,
#  'kadeem': 3630,
#  '08712400603': 99,
#  'aren': 992,
#  'dave': 2052,
#  'bedrm': 1205,
#  'wrnog': 7094,
#  'somone': 5859,
#  'match': 4094,
#  'ibhltd': 3336,
#  'prsn': 5092,
#  'dontmatter': 2272,
#  '4t': 511,
#  'player': 4875,
#  'worse': 7072,
#  'mailed': 4036,
#  'buns': 1465,
#  'virgin': 6784,
#  'footie': 2736,
#  'shock': 5674,
#  'box61': 1374,
#  'arent': 993,
#  'apparently': 961,
#  'debating': 2071,
#  'lanka': 3748,
#  'sold': 5844,
#  'receipts': 5236,
#  'married': 4082,
#  'lands': 3745,
#  'dropped': 2320,
#  '11pm': 265,
#  'disappeared': 2205,
#  'sambar': 5489,
#  'wanting': 6860,
#  'busty': 1478,
#  'muchxxlove': 4332,
#  'anniversary': 920,
#  '08712103738': 93,
#  'slave': 5771,
#  'problems': 5049,
#  'mate': 4096,
#  'eat': 2369,
#  'fink': 2674,
#  'barred': 1155,
#  '350': 432,
#  'cm2': 1755,
#  'oso': 4645,
#  'watching': 6880,
#  'lips': 3867,
#  'chatlines': 1645,
#  'steve': 6020,
#  'bloo': 1307,
#  'calls': 1521,
#  'regular': 5280,
#  'max6': 4108,
#  '3lions': 448,
#  'jsco': 3604,
#  'weekly': 6922,
#  '5we': 552,
#  'beta': 1240,
#  'patients': 4745,
#  'rajini': 5171,
#  'xoxo': 7122,
#  'wif': 6977,
#  'mesages': 4161,
#  'breathe': 1403,
#  'quarter': 5137,
#  'stars': 5991,
#  'busy': 1479,
#  'cc100p': 1594,
#  'bcoz': 1186,
#  'rebooting': 5231,
#  'nothin': 4508,
#  'city': 1715,
#  'town': 6504,
#  'getiing': 2908,
#  'hillsborough': 3209,
#  'eatin': 2371,
#  'like': 3840,
#  'paru': 4729,
#  'pages': 4686,
#  'mayb': 4110,
#  '1st4terms': 325,
#  'forfeit': 2745,
#  'alibi': 879,
#  'youdoing': 7172,
#  '20p': 344,
#  '63miles': 566,
#  '08700435505150p': 70,
#  'apples': 967,
#  'haiyoh': 3087,
#  'suppose': 6160,
#  'tongued': 6474,
#  'feels': 2623,
#  'lift': 3834,
#  'press': 5017,
#  'pile': 4847,
#  'web2mobile': 6906,
#  'juan': 3608,
#  'meant': 4121,
#  'geeeee': 2889,
#  'rude': 5443,
#  'pen': 4770,
#  'orange': 4626,
#  'halla': 3092,
#  'riddance': 5380,
#  'darkest': 2036,
#  'sw7': 6179,
#  'mf': 4171,
#  'ntt': 4522,
#  'services': 5609,
#  '86888': 665,
#  'quitting': 5150,
#  'prospects': 5085,
#  'm8': 4006,
#  'spook': 5951,
#  'cherthala': 1669,
#  'mobiles': 4247,
#  'alive': 880,
#  'bt': 1443,
#  '2moro': 389,
#  'takin': 6231,
#  'speedchat': 5919,
#  'months': 4282,
#  '41685': 471,
#  'l8er': 3719,
#  'lengths': 3807,
#  'significance': 5723,
#  'justify': 3624,
#  'xxsp': 7126,
#  'bluray': 1320,
#  'released': 5288,
#  'thecd': 6350,
#  'netun': 4433,
#  'lt': 3974,
#  '8027': 626,
#  'sleepin': 5773,
#  'george': 2904,
#  'park': 4720,
#  'thirtyeight': 6374,
#  'cann': 1537,
#  'nookii': 4490,
#  'gent': 2897,
#  'joy': 3600,
#  'later': 3762,
#  'speed': 5918,
#  'address': 790,
#  'gang': 2861,
#  'kothi': 3712,
#  'hussey': 3325,
#  '85': 655,
#  'handsome': 3103,
#  'times': 6419,
#  'idc': 3350,
#  'recharged': 5246,
#  'shahjahan': 5630,
#  'gudni8': 3051,
#  'schools': 5528,
#  'meetin': 4131,
#  'youphone': 7174,
#  '83600': 647,
#  'treasure': 6528,
#  'rael': 5162,
#  'eightish': 2400,
#  'sending': 5592,
#  'cartons': 1570,
#  'searching': 5553,
#  'shorts': 5689,
#  'hope': 3260,
#  'sends': 5593,
#  'necessary': 4408,
#  '50perweeksub': 527,
#  'videophones': 6766,
#  'news': 4447,
#  'tiz': 6436,
#  'placement': 4864,
#  'event': 2490,
#  'sleepwell': 5777,
#  'walkabout': 6842,
#  'total': 6497,
#  'dungerees': 2344,
#  'cabin': 1498,
#  'blessings': 1298,
#  'ones': 4596,
#  '2mro': 394,
#  'hello': 3178,
#  'autocorrect': 1083,
#  'mentionned': 4154,
#  '09050000460': 153,
#  'cheered': 1661,
#  'oscar': 4644,
#  'panther': 4702,
#  'bookshelf': 1340,
#  'kill': 3676,
#  'skirt': 5765,
#  'deliver': 2106,
#  '5th': 550,
#  'er': 2457,
#  'nice': 4453,
#  'somewhat': 5856,
#  'snatch': 5825,
#  'complementary': 1819,
#  'txtin': 6594,
#  'specialisation': 5912,
#  'test': 6316,
#  'blow': 1311,
#  'dancing': 2028,
#  'dificult': 2183,
#  'fizz': 2687,
#  'vpod': 6809,
#  'silently': 5727,
#  'mall': 4050,
#  'dependable': 2125,
#  'blind': 1299,
#  'works': 7064,
#  'jones': 3595,
#  'muz': 4354,
#  'menu': 4156,
#  'thank': 6336,
#  'drpd': 2322,
#  'graphics': 3011,
#  'infact': 3421,
#  'asian': 1030,
#  'underwear': 6636,
#  'sooo': 5871,
#  'mummy': 4339,
#  'fromwrk': 2816,
#  'whenevr': 6959,
#  'fact': 2562,
#  'gautham': 2874,
#  'glass': 2939,
#  'langport': 3746,
#  'secretary': 5561,
#  'dress': 2307,
#  'dabbles': 2017,
#  'rem': 5292,
#  'apologize': 958,
#  'hearing': 3161,
#  'place': 4862,
#  'nbme': 4401,
#  'hook': 3257,
#  'algarve': 875,
#  'vijaykanth': 6772,
#  'pobox84': 4906,
#  'monkeys': 4274,
#  '09058091870': 167,
#  't91': 6213,
#  'fooled': 2732,
#  'wid': 6975,
#  'children': 1683,
#  'ticket': 6406,
#  'late': 3760,
#  'lotr': 3941,
#  'yup': 7189,
#  'gei': 2890,
#  '88088': 677,
#  'prabu': 4978,
#  'pocked': 4908,
#  'living': 3885,
#  'tscs087147403231winawk': 6562,
#  'search': 5552,
#  'patent': 4741,
#  'evaporated': 2485,
#  'cave': 1590,
#  'able': 734,
#  'canada': 1529,
#  'musthu': 4353,
#  'bcmsfwc1n3xx': 1185,
#  'sum': 6136,
#  'welp': 6936,
#  'nikiyu4': 4465,
#  'thanks2': 6338,
#  'innu': 3440,
#  'kolathupalayam': 3706,
#  '08715203685': 120,
#  'imp': 3384,
#  '08712101358': 92,
#  'wonderful': 7045,
#  'flim': 2701,
#  'tariffs': 6249,
#  ...}

# %%
# transforming the train and test datasets
X_train_transformed = vect.transform(X_train)
X_test_transformed =vect.transform(X_test)

# %%
# note that the type is transformed matrix
print(type(X_train_transformed))
print(X_train_transformed)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
#   (0, 50)	1
#   (0, 264)	1
#   (0, 509)	1
#   (0, 1527)	1
#   (0, 1971)	1
#   (0, 2780)	2
#   (0, 3089)	1
#   (0, 3763)	1
#   (0, 3852)	1
#   (0, 4248)	1
#   (0, 4624)	1
#   (0, 4626)	1
#   (0, 4818)	1
#   (0, 4822)	1
#   (0, 5027)	1
#   (0, 5310)	1
#   (0, 6673)	1
#   (1, 2169)	1
#   (1, 6028)	1
#   (1, 6545)	1
#   (2, 98)	1
#   (2, 563)	1
#   (2, 1867)	1
#   (2, 2436)	1
#   (2, 3180)	1
#   :	:
#   (4176, 3879)	1
#   (4176, 4417)	1
#   (4176, 5229)	1
#   (4176, 6191)	1
#   (4176, 7134)	1
#   (4177, 254)	1
#   (4177, 307)	1
#   (4177, 358)	1
#   (4177, 831)	1
#   (4177, 2046)	1
#   (4177, 2704)	1
#   (4177, 3585)	1
#   (4177, 3623)	1
#   (4177, 4130)	1
#   (4177, 4315)	1
#   (4177, 4771)	1
#   (4177, 5234)	1
#   (4177, 5321)	1
#   (4177, 5487)	1
#   (4177, 5620)	1
#   (4177, 6321)	1
#   (4177, 6374)	1
#   (4177, 6453)	1
#   (4178, 1643)	1
#   (4178, 5817)	1

# %%
# training the NB model and making predictions
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()

# fit
mnb.fit(X_train_transformed,y_train)

# predict class
y_pred_class = mnb.predict(X_test_transformed)

# predict probabilities
y_pred_proba =mnb.predict_proba(X_test_transformed)


# printing the overall accuracy
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.9877961234745154

# %%
# note that alpha=1 is used by default for smoothing
mnb
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
# confusion matrix
metrics.confusion_matrix(y_test, y_pred_class)
# Out:
# array([[1201,    7],
#        [  10,  175]], dtype=int64)

# %%
confusion = metrics.confusion_matrix(y_test, y_pred_class)
print(confusion)
#[row, column]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]
TP = confusion[1, 1]
# Out:
# [[1201    7]
#  [  10  175]]

# %%
sensitivity = TP / float(FN + TP)
print("sensitivity",sensitivity)
# Out:
# sensitivity 0.9459459459459459

# %%
specificity = TN / float(TN + FP)

print("specificity",specificity)
# Out:
# specificity 0.9942052980132451

# %%
precision = TP / float(TP + FP)

print("precision",precision)
print(metrics.precision_score(y_test, y_pred_class))
# Out:
# precision 0.9615384615384616
# 0.9615384615384616

# %%
print("precision",precision)
print("PRECISION SCORE :",metrics.precision_score(y_test, y_pred_class))
print("RECALL SCORE :", metrics.recall_score(y_test, y_pred_class))
print("F1 SCORE :",metrics.f1_score(y_test, y_pred_class))
# Out:
# precision 0.9615384615384616
# PRECISION SCORE : 0.9615384615384616
# RECALL SCORE : 0.9459459459459459
# F1 SCORE : 0.9536784741144414

# %%
y_pred_class
# Out:
# array([0, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
y_pred_proba
# Out:
# array([[9.95239557e-01, 4.76044325e-03],
#        [9.99852357e-01, 1.47642544e-04],
#        [9.27878579e-01, 7.21214213e-02],
#        ...,
#        [9.99999671e-01, 3.28799076e-07],
#        [3.72703622e-09, 9.99999996e-01],
#        [9.99999985e-01, 1.46852511e-08]])
