# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas is a library built using NumPy specifically for data analysis. You'll be using Pandas heavily for data manipulation, visualisation, building machine learning models, etc.
#
# There are two main data structures in Pandas - Series and Dataframes. The default way to store data is dataframes, and thus manipulating dataframes quickly is probably the most important skill set for data analysis.
#
# <img src="pandas_1.png">
#
# *source: https://pandas.pydata.org/pandas-docs/stable/overview.html*
#
# In this section, you will study:
# 1. The pandas Series (similar to a numpy array)
#     * Creating a pandas series
#     * Indexing series
# 2. Dataframes
#     * Creating dataframes from dictionaries
#     * Importing CSV data files as pandas dataframes
#     * Reading and summarising dataframes
#     * Sorting dataframes

# %% [markdown]
# ### 1. The Pandas Series
#
# A series is similar to a 1-D numpy array, and contains scalar values of the same type (numeric, character, datetime etc.).
# A dataframe is simply a table where each column is a pandas series.

# %% [markdown]
# #### Creating Pandas Series
#
# Series are one-dimensional array-like structures, though unlike numpy arrays, they often contain non-numeric data (characters, dates, time, booleans etc.)
#
# You can create pandas series from array-like objects using ```pd.Series()```.

# %%
# import pandas, pd is an alias
import pandas as pd

# Creating a numeric pandas series
first_series = pd.Series([14, 8, 7, 29, 2, 37,1,5])
print(first_series)
print(type(first_series))
# Out:
# 0    14
# 1     8
# 2     7
# 3    29
# 4     2
# 5    37
# 6     1
# 7     5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Note that each element in the Series has an index, and the index starts at 0 as usual.

# %%
# Character series

character_series = pd.Series(['y', 't', 'abc', 'we'])
character_series
# Out:
# 0      y
# 1      t
# 2    abc
# 3     we
# dtype: object

# %%
object_series = pd.Series(['a', 3, 4.5, 'we'])
object_series
# Out:
# 0      a
# 1      3
# 2    4.5
# 3     we
# dtype: object

# %%
# creating a series of datetime type

datetime_series = pd.date_range(start = '5-8-2018', end = '12-31-2025', freq='y')
print(datetime_series)
type(datetime_series)
# Out:
# DatetimeIndex(['2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31',
#                '2022-12-31', '2023-12-31', '2024-12-31', '2025-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# #### Indexing Series
#
# Indexing series is exactly same as 1-D numpy arrays - index starts at 0.

# %%
# Indexing pandas series: Similar to indexing 1-d numpy arrays or lists
# accessing the third element
first_series[2]
# Out:
# 7

# %%
# accessing elements starting index = 1 till the end
first_series[1:]
# Out:
# 1     8
# 2     7
# 3    29
# 4     2
# 5    37
# 6     1
# 7     5
# dtype: int64

# %%
# accessing the second and the fourth elements
# note that first_series[1, 3] will not work, you need to pass the indices [1, 3] as a list inside the original []
first_series[[4,7]]
# Out:
# 4    2
# 7    5
# dtype: int64

# %% [markdown]
# Usually, you will work with Series only as a part of dataframes. Let's study the basics of dataframes.

# %% [markdown]
# ### The Pandas Dataframe
#
# Dataframe is the most widely used data-structure in data analysis. It is a table with rows and columns, with rows having an index and columns having meaningful names.

# %% [markdown]
# #### Creating dataframes from dictionaries
#
# There are various ways of creating dataframes, such as creating them from dictionaries, JSON objects, reading from txt, CSV files, etc.

# %%
# keys become column names
df = pd.DataFrame({'name': ['Vinay', 'Kushal', 'Aman', 'Saif'], 
                   'age': [22, 25, 24, 28,8], 
                    'occupation': ['engineer', 'doctor', 'data analyst', 'teacher']})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-cdaf5c38b053> in <module>
#       2 df = pd.DataFrame({'name': ['Vinay', 'Kushal', 'Aman', 'Saif'],
#       3                    'age': [22, 25, 24, 28,8],
# ----> 4                     'occupation': ['engineer', 'doctor', 'data analyst', 'teacher']})
#       5 df
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    7400             lengths = list(set(raw_lengths))
#    7401             if len(lengths) > 1:
# -> 7402                 raise ValueError('arrays must all be same length')
#    7403
#    7404             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# #### Importing CSV data files as pandas dataframes
#
# For the upcoming exercises, we will use a dataset of a retail store having details about the orders placed, customers, product details, sales, profits etc.

# %%
# reading a CSV file as a dataframe
ticket_df = pd.read_csv("./global_sales_data/Ticket_data_New.csv")

#head() always returns the first 5 rows
ticket_df.head(8)
# Out:
#        Number               Opened Task type      Priority     State  \
# 0  INC0073572  18/04/2018 19:07:53  Incident      2 - High   On Hold
# 1  INC0073024  17/04/2018 15:08:44  Incident       4 - Low   On Hold
# 2  INC0073023  17/04/2018 15:08:31  Incident       4 - Low   On Hold
# 3  INC0072924  17/04/2018 09:35:10  Incident  1 - Critical  Resolved
# 4  INC0072821  17/04/2018 00:26:02  Incident  3 - Moderate  Resolved
# 5  INC0072519  16/04/2018 09:13:41  Incident  3 - Moderate    Closed
# 6  INC0072056  13/04/2018 14:52:34  Incident  3 - Moderate   On Hold
# 7  INC0071701          43438.51061  Incident      2 - High    Closed
#
#    Assignment group Assigned to              Updated Updated by  \
# 0  FMS Support Team        Babu  18/04/2018 21:10:27       Babu
# 1  MSS Support Team       Rahul  17/04/2018 16:09:35      Rahul
# 2  FMS Support Team        Saif  18/04/2018 10:39:59       Saif
# 3  FMS Support Team     Krishna  17/04/2018 20:31:43    Krishna
# 4  FMS Support Team       Vamsi  17/04/2018 22:09:47      Vamsi
# 5  FMS Support Team      Rajesh  16/04/2018 15:35:18     Rajesh
# 6  FMS Support Team        Saif  13/04/2018 15:56:49       Saif
# 7  FMS Support Team       Rahul  17/04/2018 19:00:06      Rahul
#
#                 Closed Closed by
# 0                  NaN      Babu
# 1                  NaN     Rahul
# 2                  NaN      Saif
# 3                  NaN   Krishna
# 4                  NaN     Vamsi
# 5  16/04/2018 15:35:18    Rajesh
# 6                  NaN      Saif
# 7  17/04/2018 19:00:06     Rahul

# %%
ticket_df.tail(10)
# Out:
#         Number       Opened Task type      Priority    State  \
# 16  INC0070574  43347.59802  Incident       4 - Low   Closed
# 17  INC0070332  43316.55322  Incident       4 - Low   Closed
# 18  INC0070018  43255.72841  Incident  3 - Moderate   Closed
# 19  INC0069946  43255.55411  Incident       4 - Low   Closed
# 20  INC0069940  43255.53656  Incident       4 - Low  On Hold
# 21  INC0069939  43255.52418  Incident       4 - Low   Closed
# 22  INC0069907  43255.42479  Incident       4 - Low  On Hold
# 23  INC0069608  43224.57965  Incident       4 - Low   Closed
# 24  INC0069516  43224.21356  Incident  3 - Moderate   Closed
# 25  INC0069438  43194.91313  Incident       4 - Low   Closed
#
#     Assignment group Assigned to              Updated Updated by  \
# 16  FMS Support Team     Krishna  15/04/2018 22:00:06    Krishna
# 17  FMS Support Team     Krishna  14/04/2018 01:00:03    Krishna
# 18  FMS Support Team       Vamsi          43408.52895      Vamsi
# 19  FMS Support Team       Rahul  18/04/2018 17:00:03      Rahul
# 20  FMS Support Team       Vamsi  13/04/2018 18:01:33      Vamsi
# 21  FMS Support Team     Krishna  18/04/2018 17:00:08    Krishna
# 22  MMS Support Team       Rahul          43255.75743      Rahul
# 23  FMS Support Team       Vamsi          43377.62538      Vamsi
# 24  FMS Support Team       Vamsi           43438.0002      Vamsi
# 25  MMS Support Team     Krishna          43347.95846    Krishna
#
#                  Closed Closed by
# 16  15/04/2018 22:00:06   Krishna
# 17  14/04/2018 01:00:03   Krishna
# 18          43408.52895     Vamsi
# 19  18/04/2018 17:00:03     Rahul
# 20                  NaN     Vamsi
# 21  18/04/2018 17:00:08   Krishna
# 22                  NaN     Rahul
# 23          43377.62538     Vamsi
# 24           43438.0002     Vamsi
# 25          43347.95846   Krishna

# %% [markdown]
# Usually, dataframes are imported as CSV files, but sometimes it is more convenient to convert dictionaries
# into dataframes. For e.g. when the raw data is in a JSON format (which is not uncommon), you can easily convert it into a dictionary, and then into a dataframe.
#
# You will learn how to convert JSON objects to dataframes later.

# %% [markdown]
# #### Reading and Summarising Dataframes
#
# After you import a dataframe, you'd want to quickly understand its structure, shape, meanings of rows and columns etc. Further, you may want to look at summary statistics - such as mean, percentiles etc.

# %%
#tail() always gives last 5 rows in the dataframe
ticket_df.tail(10)

# %% [markdown]
# Here, each row represents an order placed at a retail store. Notice the index associated with each row - starts at 0 and ends at 8398, implying that there were 8399 orders placed.

# %%
# Looking at the datatypes of each column
ticket_df.info()

# Note that each column is basically a pandas Series of length 8399
# The ID columns are 'objects', i.e. they are being read as characters
# The rest are numeric (floats or int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 11 columns):
# Number              26 non-null object
# Opened              26 non-null object
# Task type           26 non-null object
# Priority            26 non-null object
# State               26 non-null object
# Assignment group    26 non-null object
# Assigned to         26 non-null object
# Updated             26 non-null object
# Updated by          26 non-null object
# Closed              15 non-null object
# Closed by           26 non-null object
# dtypes: object(11)
# memory usage: 2.3+ KB

# %%
# Describe gives you a summary of all the numeric columns in the dataset
ticket_df.describe()
# Out:
#             Number       Opened Task type Priority   State  Assignment group  \
# count           26           26        26       26      26                26
# unique          26           26         1        4       4                 3
# top     INC0070332  43347.67469  Incident  4 - Low  Closed  FMS Support Team
# freq             1            1        26       13      14                23
#
#        Assigned to              Updated Updated by               Closed  \
# count           26                   26         26                   15
# unique           6                   26          6                   15
# top        Krishna  15/04/2018 21:00:08    Krishna  15/04/2018 21:00:08
# freq             8                    1          8                    1
#
#        Closed by
# count         26
# unique         6
# top      Krishna
# freq           8

# %%
# Column names
ticket_df.columns
# Out:
# Index(['Number', 'Opened', 'Task type', 'Priority', 'State',
#        'Assignment group', 'Assigned to', 'Updated', 'Updated by', 'Closed',
#        'Closed by'],
#       dtype='object')

# %%
# The number of rows and columns
ticket_df.shape
# Out:
# (26, 11)

# %%
# You can extract the values of a dataframe as a numpy array using df.values . In this example we are printing only first 2 values
ticket_df.values[0:2]
# Out:
# array([['INC0073572', '18/04/2018 19:07:53', 'Incident', '2 - High',
#         'On Hold', 'FMS Support Team', 'Babu', '18/04/2018 21:10:27',
#         'Babu', nan, 'Babu'],
#        ['INC0073024', '17/04/2018 15:08:44', 'Incident', '4 - Low',
#         'On Hold', 'MSS Support Team', 'Rahul', '17/04/2018 16:09:35',
#         'Rahul', nan, 'Rahul']], dtype=object)

# %% [markdown]
# #### Indices
#
# An important concept in pandas dataframes is that of *row indices*. By default, each row is assigned indices starting from 0, and are represented at the left side of the dataframe.

# %%
#Error is expected here. Dataframe gets confused which indice you are trying. Column or row?
print(ticket_df[2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-65c6d567a470> in <module>
#       1 #Error is expected here. Dataframe gets confused which indice you are trying. Column or row?
# ----> 2 print(ticket_df[2])
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2

# %%
ticket_df.head()
sort_df_number =ticket_df.sort_values(by='Number', ascending=False)
sort_df_number
# Out:
#         Number               Opened Task type      Priority     State  \
# 0   INC0073572  18/04/2018 19:07:53  Incident      2 - High   On Hold
# 1   INC0073024  17/04/2018 15:08:44  Incident       4 - Low   On Hold
# 2   INC0073023  17/04/2018 15:08:31  Incident       4 - Low   On Hold
# 3   INC0072924  17/04/2018 09:35:10  Incident  1 - Critical  Resolved
# 4   INC0072821  17/04/2018 00:26:02  Incident  3 - Moderate  Resolved
# 5   INC0072519  16/04/2018 09:13:41  Incident  3 - Moderate    Closed
# 6   INC0072056  13/04/2018 14:52:34  Incident  3 - Moderate   On Hold
# 7   INC0071701          43438.51061  Incident      2 - High    Closed
# 8   INC0071459          43408.78726  Incident  3 - Moderate  Resolved
# 9   INC0071094          43377.84138  Incident       4 - Low    Closed
# 10  INC0070986          43377.61885  Incident       4 - Low    Closed
# 11  INC0070699          43347.76417  Incident       4 - Low   On Hold
# 12  INC0070694          43347.75521  Incident      2 - High  Resolved
# 13  INC0070631          43347.67469  Incident      2 - High    Closed
# 14  INC0070604          43347.64711  Incident      2 - High  Canceled
# 15  INC0070577          43347.60428  Incident  3 - Moderate    Closed
# 16  INC0070574          43347.59802  Incident       4 - Low    Closed
# 17  INC0070332          43316.55322  Incident       4 - Low    Closed
# 18  INC0070018          43255.72841  Incident  3 - Moderate    Closed
# 19  INC0069946          43255.55411  Incident       4 - Low    Closed
# 20  INC0069940          43255.53656  Incident       4 - Low   On Hold
# 21  INC0069939          43255.52418  Incident       4 - Low    Closed
# 22  INC0069907          43255.42479  Incident       4 - Low   On Hold
# 23  INC0069608          43224.57965  Incident       4 - Low    Closed
# 24  INC0069516          43224.21356  Incident  3 - Moderate    Closed
# 25  INC0069438          43194.91313  Incident       4 - Low    Closed
#
#     Assignment group Assigned to              Updated Updated by  \
# 0   FMS Support Team        Babu  18/04/2018 21:10:27       Babu
# 1   MSS Support Team       Rahul  17/04/2018 16:09:35      Rahul
# 2   FMS Support Team        Saif  18/04/2018 10:39:59       Saif
# 3   FMS Support Team     Krishna  17/04/2018 20:31:43    Krishna
# 4   FMS Support Team       Vamsi  17/04/2018 22:09:47      Vamsi
# 5   FMS Support Team      Rajesh  16/04/2018 15:35:18     Rajesh
# 6   FMS Support Team        Saif  13/04/2018 15:56:49       Saif
# 7   FMS Support Team       Rahul  17/04/2018 19:00:06      Rahul
# 8   FMS Support Team     Krishna  18/04/2018 19:31:41    Krishna
# 9   FMS Support Team        Saif  15/04/2018 21:00:08       Saif
# 10  FMS Support Team        Saif  16/04/2018 18:00:08       Saif
# 11  FMS Support Team     Krishna          43347.80557    Krishna
# 12  FMS Support Team       Rahul  17/04/2018 13:39:33      Rahul
# 13  FMS Support Team     Krishna          43347.74354    Krishna
# 14  FMS Support Team       Vamsi          43347.79096      Vamsi
# 15  FMS Support Team        Saif  14/04/2018 19:00:12       Saif
# 16  FMS Support Team     Krishna  15/04/2018 22:00:06    Krishna
# 17  FMS Support Team     Krishna  14/04/2018 01:00:03    Krishna
# 18  FMS Support Team       Vamsi          43408.52895      Vamsi
# 19  FMS Support Team       Rahul  18/04/2018 17:00:03      Rahul
# 20  FMS Support Team       Vamsi  13/04/2018 18:01:33      Vamsi
# 21  FMS Support Team     Krishna  18/04/2018 17:00:08    Krishna
# 22  MMS Support Team       Rahul          43255.75743      Rahul
# 23  FMS Support Team       Vamsi          43377.62538      Vamsi
# 24  FMS Support Team       Vamsi           43438.0002      Vamsi
# 25  MMS Support Team     Krishna          43347.95846    Krishna
#
#                  Closed Closed by
# 0                   NaN      Babu
# 1                   NaN     Rahul
# 2                   NaN      Saif
# 3                   NaN   Krishna
# 4                   NaN     Vamsi
# 5   16/04/2018 15:35:18    Rajesh
# 6                   NaN      Saif
# 7   17/04/2018 19:00:06     Rahul
# 8                   NaN   Krishna
# 9   15/04/2018 21:00:08      Saif
# 10  16/04/2018 18:00:08      Saif
# 11                  NaN   Krishna
# 12                  NaN     Rahul
# 13          43347.74354   Krishna
# 14          43347.79096     Vamsi
# 15  14/04/2018 19:00:12      Saif
# 16  15/04/2018 22:00:06   Krishna
# 17  14/04/2018 01:00:03   Krishna
# 18          43408.52895     Vamsi
# 19  18/04/2018 17:00:03     Rahul
# 20                  NaN     Vamsi
# 21  18/04/2018 17:00:08   Krishna
# 22                  NaN     Rahul
# 23          43377.62538     Vamsi
# 24           43438.0002     Vamsi
# 25          43347.95846   Krishna

# %% [markdown]
# Now, arbitrary numeric indices are difficult to read and work with. Thus, you may want to change the indices of the df to something more meanigful.
#
# Let's change the index to Incident Number (unique id of each order), so that you can select rows using the order ids directly.

# %%
# Setting index to Ord_id
ticket_df.set_index('Number', inplace = True)
ticket_df.head()
# Out:
#                          Opened Task type      Priority     State  \
# Number
# INC0073572  18/04/2018 19:07:53  Incident      2 - High   On Hold
# INC0073024  17/04/2018 15:08:44  Incident       4 - Low   On Hold
# INC0073023  17/04/2018 15:08:31  Incident       4 - Low   On Hold
# INC0072924  17/04/2018 09:35:10  Incident  1 - Critical  Resolved
# INC0072821  17/04/2018 00:26:02  Incident  3 - Moderate  Resolved
#
#             Assignment group Assigned to              Updated Updated by  \
# Number
# INC0073572  FMS Support Team        Babu  18/04/2018 21:10:27       Babu
# INC0073024  MSS Support Team       Rahul  17/04/2018 16:09:35      Rahul
# INC0073023  FMS Support Team        Saif  18/04/2018 10:39:59       Saif
# INC0072924  FMS Support Team     Krishna  17/04/2018 20:31:43    Krishna
# INC0072821  FMS Support Team       Vamsi  17/04/2018 22:09:47      Vamsi
#
#            Closed Closed by
# Number
# INC0073572    NaN      Babu
# INC0073024    NaN     Rahul
# INC0073023    NaN      Saif
# INC0072924    NaN   Krishna
# INC0072821    NaN     Vamsi

# %% [markdown]
# Having meaningful row labels as indices helps you to select (subset) dataframes easily. You will study selecting dataframes in the next section.

# %% [markdown]
# #### Sorting dataframes
#
# You can sort dataframes in two ways - 1) by the indices and 2) by the values.

# %%
#Error is expected. This is not the way you select a row in Dataframe
ticket_df['INC0072821']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'INC0072821'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-9bf376b00d4b> in <module>
#       1 #Error is expected. This is not the way you select a row in Dataframe
# ----> 2 ticket_df['INC0072821']
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'INC0072821'

# %%
# Sorting by index
# axis = 0 indicates that you want to sort rows (use axis=1 for columns)
sort_df = ticket_df.sort_index(axis = 0, ascending = True)
sort_df.head()
# Out:
#                  Opened Task type      Priority    State  Assignment group  \
# Number
# INC0069438  43194.91313  Incident       4 - Low   Closed  MMS Support Team
# INC0069516  43224.21356  Incident  3 - Moderate   Closed  FMS Support Team
# INC0069608  43224.57965  Incident       4 - Low   Closed  FMS Support Team
# INC0069907  43255.42479  Incident       4 - Low  On Hold  MMS Support Team
# INC0069939  43255.52418  Incident       4 - Low   Closed  FMS Support Team
#
#            Assigned to              Updated Updated by               Closed  \
# Number
# INC0069438     Krishna          43347.95846    Krishna          43347.95846
# INC0069516       Vamsi           43438.0002      Vamsi           43438.0002
# INC0069608       Vamsi          43377.62538      Vamsi          43377.62538
# INC0069907       Rahul          43255.75743      Rahul                  NaN
# INC0069939     Krishna  18/04/2018 17:00:08    Krishna  18/04/2018 17:00:08
#
#            Closed by
# Number
# INC0069438   Krishna
# INC0069516     Vamsi
# INC0069608     Vamsi
# INC0069907     Rahul
# INC0069939   Krishna

# %%
# Sorting by values

# Sorting in increasing order of Sales
sort_df_prior = ticket_df.sort_values(by='Priority')
sort_df_prior.head(12)
# Out:
#                          Opened Task type      Priority     State  \
# Number
# INC0072924  17/04/2018 09:35:10  Incident  1 - Critical  Resolved
# INC0073572  18/04/2018 19:07:53  Incident      2 - High   On Hold
# INC0070604          43347.64711  Incident      2 - High  Canceled
# INC0070631          43347.67469  Incident      2 - High    Closed
# INC0071701          43438.51061  Incident      2 - High    Closed
# INC0070694          43347.75521  Incident      2 - High  Resolved
# INC0072056  13/04/2018 14:52:34  Incident  3 - Moderate   On Hold
# INC0070018          43255.72841  Incident  3 - Moderate    Closed
# INC0072519  16/04/2018 09:13:41  Incident  3 - Moderate    Closed
# INC0069516          43224.21356  Incident  3 - Moderate    Closed
# INC0070577          43347.60428  Incident  3 - Moderate    Closed
# INC0071459          43408.78726  Incident  3 - Moderate  Resolved
#
#             Assignment group Assigned to              Updated Updated by  \
# Number
# INC0072924  FMS Support Team     Krishna  17/04/2018 20:31:43    Krishna
# INC0073572  FMS Support Team        Babu  18/04/2018 21:10:27       Babu
# INC0070604  FMS Support Team       Vamsi          43347.79096      Vamsi
# INC0070631  FMS Support Team     Krishna          43347.74354    Krishna
# INC0071701  FMS Support Team       Rahul  17/04/2018 19:00:06      Rahul
# INC0070694  FMS Support Team       Rahul  17/04/2018 13:39:33      Rahul
# INC0072056  FMS Support Team        Saif  13/04/2018 15:56:49       Saif
# INC0070018  FMS Support Team       Vamsi          43408.52895      Vamsi
# INC0072519  FMS Support Team      Rajesh  16/04/2018 15:35:18     Rajesh
# INC0069516  FMS Support Team       Vamsi           43438.0002      Vamsi
# INC0070577  FMS Support Team        Saif  14/04/2018 19:00:12       Saif
# INC0071459  FMS Support Team     Krishna  18/04/2018 19:31:41    Krishna
#
#                          Closed Closed by
# Number
# INC0072924                  NaN   Krishna
# INC0073572                  NaN      Babu
# INC0070604          43347.79096     Vamsi
# INC0070631          43347.74354   Krishna
# INC0071701  17/04/2018 19:00:06     Rahul
# INC0070694                  NaN     Rahul
# INC0072056                  NaN      Saif
# INC0070018          43408.52895     Vamsi
# INC0072519  16/04/2018 15:35:18    Rajesh
# INC0069516           43438.0002     Vamsi
# INC0070577  14/04/2018 19:00:12      Saif
# INC0071459                  NaN   Krishna

# %%
# Sorting in decreasing order of Shipping_Cost
sort_df_state = ticket_df.sort_values(by='State', ascending = False)
sort_df_state.head(12)
# Out:
#                          Opened Task type      Priority     State  \
# Number
# INC0071459          43408.78726  Incident  3 - Moderate  Resolved
# INC0072924  17/04/2018 09:35:10  Incident  1 - Critical  Resolved
# INC0072821  17/04/2018 00:26:02  Incident  3 - Moderate  Resolved
# INC0070694          43347.75521  Incident      2 - High  Resolved
# INC0069907          43255.42479  Incident       4 - Low   On Hold
# INC0069940          43255.53656  Incident       4 - Low   On Hold
# INC0073024  17/04/2018 15:08:44  Incident       4 - Low   On Hold
# INC0070699          43347.76417  Incident       4 - Low   On Hold
# INC0073572  18/04/2018 19:07:53  Incident      2 - High   On Hold
# INC0072056  13/04/2018 14:52:34  Incident  3 - Moderate   On Hold
# INC0073023  17/04/2018 15:08:31  Incident       4 - Low   On Hold
# INC0070332          43316.55322  Incident       4 - Low    Closed
#
#             Assignment group Assigned to              Updated Updated by  \
# Number
# INC0071459  FMS Support Team     Krishna  18/04/2018 19:31:41    Krishna
# INC0072924  FMS Support Team     Krishna  17/04/2018 20:31:43    Krishna
# INC0072821  FMS Support Team       Vamsi  17/04/2018 22:09:47      Vamsi
# INC0070694  FMS Support Team       Rahul  17/04/2018 13:39:33      Rahul
# INC0069907  MMS Support Team       Rahul          43255.75743      Rahul
# INC0069940  FMS Support Team       Vamsi  13/04/2018 18:01:33      Vamsi
# INC0073024  MSS Support Team       Rahul  17/04/2018 16:09:35      Rahul
# INC0070699  FMS Support Team     Krishna          43347.80557    Krishna
# INC0073572  FMS Support Team        Babu  18/04/2018 21:10:27       Babu
# INC0072056  FMS Support Team        Saif  13/04/2018 15:56:49       Saif
# INC0073023  FMS Support Team        Saif  18/04/2018 10:39:59       Saif
# INC0070332  FMS Support Team     Krishna  14/04/2018 01:00:03    Krishna
#
#                          Closed Closed by
# Number
# INC0071459                  NaN   Krishna
# INC0072924                  NaN   Krishna
# INC0072821                  NaN     Vamsi
# INC0070694                  NaN     Rahul
# INC0069907                  NaN     Rahul
# INC0069940                  NaN     Vamsi
# INC0073024                  NaN     Rahul
# INC0070699                  NaN   Krishna
# INC0073572                  NaN      Babu
# INC0072056                  NaN      Saif
# INC0073023                  NaN      Saif
# INC0070332  14/04/2018 01:00:03   Krishna

# %%
# Sorting by more than two columns

# Sorting in ascending order of Sales for each Product
sort_df_state_prior= ticket_df.sort_values(by=['State', 'Priority'], ascending = False)
sort_df_state_prior.head(12)
