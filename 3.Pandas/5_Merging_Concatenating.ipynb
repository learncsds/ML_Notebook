# %% [markdown]
# # Merging and Concatenating Dataframes
#
#
# In this section, you will merge and concatenate multiple dataframes. Merging is one of the most common operations you will do, since data often comes in various files.
#
# In our case, we have sales data of a retail store spread across multiple files. We will now work with all these data files and learn to:
# * Merge multiple dataframes using common columns/keys using ```pd.merge()```
# * Concatenate dataframes using ```pd.concat()```
#
# Let's first read all the data files.

# %%
# loading libraries and reading the data
import numpy as np
import pandas as pd

market_df = pd.read_csv("./global_sales_data/market_fact.csv")
customer_df = pd.read_csv("./global_sales_data/cust_dimen.csv")
product_df = pd.read_csv("./global_sales_data/prod_dimen.csv")
shipping_df = pd.read_csv("./global_sales_data/shipping_dimen.csv")
orders_df = pd.read_csv("./global_sales_data/orders_dimen.csv")

# %% [markdown]
# ### Merging Dataframes Using ```pd.merge()```
#
# There are five data files:
# 1. The ```market_fact``` table contains the sales data of each order
# 2. The other 4 files are called 'dimension tables/files' and contain metadata about customers, products, shipping details, order details etc.
#
# If you are familiar with star schemas and data warehouse designs, you will note that we have one fact table and four dimension tables.

# %%
# Already familiar with market data: Each row is an order
market_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
# Customer dimension table: Each row contains metadata about customers
customer_df.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
# Product dimension table
product_df.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
# Shipping metadata
shipping_df.head()
# Out:
#    Order_ID       Ship_Mode   Ship_Date Ship_id
# 0         3     REGULAR AIR  20-10-2010   SHP_1
# 1       293  DELIVERY TRUCK  02-10-2012   SHP_2
# 2       293     REGULAR AIR  03-10-2012   SHP_3
# 3       483     REGULAR AIR  12-07-2011   SHP_4
# 4       515     REGULAR AIR  30-08-2010   SHP_5

# %%
# Orders dimension table
orders_df.head()
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %% [markdown]
# ### Merging Dataframes
#
# Say you want to select all orders and observe the ```Sales``` of the customer segment *Corporate*. Since customer segment details are present in the dataframe ```customer_df```, we will first need to merge it with ```market_df```.

# %%
# Merging the dataframes
# Note that Cust_id is the common column/key, which is provided to the 'on' argument
# how = 'inner' makes sure that only the customer ids present in both dfs are included in the result
df_1 = pd.merge(market_df, customer_df, how='inner', on='Cust_id')
df_1.iloc[0:1000,:]
# Out:
#        Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0    Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1    Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2    Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3    Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4    Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5    Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6      Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7    Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8    Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9    Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10   Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11   Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12   Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# 13   Ord_2207  Prod_11  SHP_3093   Cust_839   3364.2480      0.10
# 14   Ord_2207  Prod_10  SHP_3006   Cust_839   1410.9300      0.08
# 15   Ord_2280   Prod_5  SHP_3114   Cust_839    460.6900      0.06
# 16   Ord_2282   Prod_9  SHP_3122   Cust_839    443.4600      0.06
# 17   Ord_4471  Prod_15  SHP_6228  Cust_1521  13255.9300      0.02
# 18   Ord_4427   Prod_6  SHP_6171  Cust_1521    283.1300      0.08
# 19    Ord_996  Prod_13  SHP_1378   Cust_371     41.9700      0.05
# 20    Ord_996  Prod_13  SHP_1378   Cust_371     57.1700      0.08
# 21    Ord_996   Prod_6  SHP_1378   Cust_371     81.2500      0.01
# 22    Ord_996   Prod_5  SHP_1377   Cust_371   3202.2500      0.09
# 23    Ord_996   Prod_7  SHP_1378   Cust_371     35.6400      0.05
# 24   Ord_2573   Prod_3  SHP_3525   Cust_931    197.6100      0.08
# 25   Ord_2335  Prod_13  SHP_3204   Cust_931     38.2600      0.03
# 26   Ord_2456   Prod_5  SHP_3367   Cust_931    109.5800      0.00
# 27   Ord_2405   Prod_9  SHP_3300   Cust_931   1062.6900      0.01
# 28   Ord_2573   Prod_4  SHP_3527   Cust_931   3594.7435      0.05
# 29   Ord_2478  Prod_12  SHP_3395   Cust_931    139.9800      0.07
# ..        ...      ...       ...        ...         ...       ...
# 970  Ord_4366   Prod_1  SHP_6086  Cust_1475    370.7200      0.10
# 971  Ord_4392   Prod_7  SHP_6123  Cust_1475     11.1500      0.07
# 972  Ord_4349   Prod_3  SHP_6064  Cust_1475     22.5600      0.04
# 973  Ord_4379  Prod_12  SHP_6103  Cust_1475     88.8200      0.01
# 974  Ord_5078   Prod_6  SHP_7091  Cust_1726    692.1500      0.09
# 975  Ord_5081   Prod_9  SHP_7094  Cust_1724    541.4700      0.05
# 976  Ord_5070   Prod_8  SHP_7079  Cust_1724    772.4200      0.02
# 977  Ord_5070   Prod_4  SHP_7079  Cust_1724    221.4675      0.00
# 978  Ord_1161   Prod_3  SHP_1603   Cust_446    251.1100      0.03
# 979  Ord_1166   Prod_1  SHP_1608   Cust_440   2954.1400      0.04
# 980  Ord_1155   Prod_8  SHP_1591   Cust_440     33.6400      0.07
# 981  Ord_1149   Prod_6  SHP_1583   Cust_440    109.3700      0.07
# 982  Ord_1148   Prod_5  SHP_1582   Cust_440    316.3500      0.06
# 983  Ord_1155  Prod_17  SHP_1592   Cust_440    701.9400      0.01
# 984  Ord_1166   Prod_4  SHP_1609   Cust_440   3375.3075      0.10
# 985  Ord_4808   Prod_4  SHP_6701  Cust_1617   1947.4265      0.03
# 986  Ord_4672   Prod_2  SHP_6513  Cust_1617   3702.9200      0.03
# 987  Ord_4672   Prod_3  SHP_6514  Cust_1617     53.9900      0.10
# 988  Ord_4804   Prod_8  SHP_6696  Cust_1599   1121.8400      0.00
# 989  Ord_4804   Prod_3  SHP_6696  Cust_1599    176.5800      0.10
# 990  Ord_4641   Prod_3  SHP_6464  Cust_1599    532.8900      0.09
# 991  Ord_4641   Prod_8  SHP_6465  Cust_1599     60.6900      0.06
# 992  Ord_4751  Prod_15  SHP_6624  Cust_1599   4480.8900      0.02
# 993  Ord_4650   Prod_3  SHP_6481  Cust_1599    229.2600      0.00
# 994  Ord_1809  Prod_11  SHP_2502   Cust_617   8532.1520      0.04
# 995  Ord_1816  Prod_13  SHP_2509   Cust_617    191.1300      0.07
# 996  Ord_1910   Prod_5  SHP_2617   Cust_699   2011.4600      0.01
# 997  Ord_2025   Prod_4  SHP_2769   Cust_686   2526.5400      0.04
# 998  Ord_1809   Prod_2  SHP_2736   Cust_686   2269.4100      0.05
# 999  Ord_1816  Prod_13  SHP_2754   Cust_686     48.2400      0.09
#
#      Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  \
# 0                23   -30.51           3.60                 0.56
# 1                13     4.56           0.93                 0.54
# 2                26  1148.90           2.50                 0.59
# 3                43   729.34          14.30                 0.37
# 4                35  1219.87          26.30                 0.38
# 5                23   -47.64           6.15                 0.37
# 6                 5     1.32           0.50                 0.36
# 7                48  1137.91           0.99                 0.55
# 8                33    45.84           0.71                 0.52
# 9                 8   -27.72           6.60                 0.37
# 10               43  1675.98           0.99                 0.56
# 11               38    79.34           4.86                 0.38
# 12               27    23.12           3.37                 0.57
# 13               15  -693.23          61.76                 0.78
# 14               10  -317.48          36.09                 0.77
# 15               48  -103.48           7.29                 0.45
# 16               30   193.12           1.39                 0.38
# 17               25  4089.27          26.00                 0.60
# 18               45  -141.26           6.81                 0.36
# 19               12   -37.03           4.20                 0.56
# 20               18   -24.03           2.31                 0.56
# 21               11   -44.54           7.86                 0.37
# 22               44   991.26          19.99                 0.43
# 23               10    -0.71           1.63                 0.36
# 24               13     3.46           7.27                 0.38
# 25               22    -2.34           0.70                 0.56
# 26               13    31.32           4.00                 0.42
# 27               28   401.80           6.66                 0.40
# 28               38  1016.97           2.50                 0.55
# 29               33  -140.54           6.89                 0.39
# ..              ...      ...            ...                  ...
# 970              24  -156.76          11.25                 0.60
# 971               6    -2.62           0.75                 0.52
# 972               5   -25.56           6.27                 0.40
# 973              20    38.35           0.50                 0.39
# 974              37   150.38           5.97                 0.38
# 975              49    90.62           4.80                 0.36
# 976              49   299.33           1.99                 0.42
# 977               3  -302.23           3.30                 0.37
# 978              30    10.04           4.71                 0.35
# 979              21  -522.94          35.00                  NaN
# 980               4   -35.17           2.83                 0.77
# 981              11    25.96           1.79                 0.38
# 982              21   117.91           3.73                 0.46
# 983              29   158.91           6.30                 0.38
# 984              34   562.13           8.08                 0.57
# 985              34   473.27           5.92                 0.55
# 986              49   541.92          19.95                 0.54
# 987              29   -15.12           1.49                 0.37
# 988              15  -173.66          12.14                 0.67
# 989               6    28.34           2.99                 0.35
# 990              43   210.53           1.49                 0.35
# 991              24   -25.65           1.99                 0.55
# 992              48   195.04          30.00                 0.61
# 993              31   -37.20           5.48                 0.37
# 994              50  -513.79          52.20                 0.64
# 995              47    38.11           1.20                 0.44
# 996              48   171.07           8.66                 0.76
# 997              46   772.11           2.50                 0.55
# 998              33   630.18           3.50                 0.59
# 999              17    -1.62           1.01                 0.55
#
#       Customer_Name          Province    Region Customer_Segment
# 0     AARON BERGMAN           ALBERTA      WEST        CORPORATE
# 1     AARON BERGMAN           ALBERTA      WEST        CORPORATE
# 2     AARON BERGMAN           ALBERTA      WEST        CORPORATE
# 3     AARON BERGMAN           ALBERTA      WEST        CORPORATE
# 4     AARON BERGMAN           ALBERTA      WEST        CORPORATE
# 5     AARON BERGMAN           ALBERTA      WEST        CORPORATE
# 6     AARON BERGMAN           NUNAVUT   NUNAVUT        CORPORATE
# 7     AARON HAWKINS  BRITISH COLUMBIA      WEST      HOME OFFICE
# 8     AARON HAWKINS  BRITISH COLUMBIA      WEST      HOME OFFICE
# 9     AARON HAWKINS  BRITISH COLUMBIA      WEST      HOME OFFICE
# 10    AARON HAWKINS  BRITISH COLUMBIA      WEST      HOME OFFICE
# 11    AARON HAWKINS       NOVA SCOTIA  ATLANTIC      HOME OFFICE
# 12    AARON HAWKINS           ONTARIO   ONTARIO      HOME OFFICE
# 13    AARON HAWKINS            QUEBEC    QUEBEC      HOME OFFICE
# 14    AARON HAWKINS            QUEBEC    QUEBEC      HOME OFFICE
# 15    AARON HAWKINS            QUEBEC    QUEBEC      HOME OFFICE
# 16    AARON HAWKINS            QUEBEC    QUEBEC      HOME OFFICE
# 17    AARON HAWKINS             YUKON     YUKON      HOME OFFICE
# 18    AARON HAWKINS             YUKON     YUKON      HOME OFFICE
# 19   AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 20   AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 21   AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 22   AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 23   AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 24   AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 25   AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 26   AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 27   AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 28   AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 29   AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# ..              ...               ...       ...              ...
# 970     BOBBY ELIAS             YUKON     YUKON   SMALL BUSINESS
# 971     BOBBY ELIAS             YUKON     YUKON   SMALL BUSINESS
# 972     BOBBY ELIAS             YUKON     YUKON   SMALL BUSINESS
# 973     BOBBY ELIAS             YUKON     YUKON   SMALL BUSINESS
# 974   BOBBY ODEGARD           ALBERTA      WEST         CONSUMER
# 975   BOBBY ODEGARD           ALBERTA      WEST        CORPORATE
# 976   BOBBY ODEGARD           ALBERTA      WEST        CORPORATE
# 977   BOBBY ODEGARD           ALBERTA      WEST        CORPORATE
# 978   BOBBY ODEGARD           ONTARIO   ONTARIO         CONSUMER
# 979   BOBBY ODEGARD           ONTARIO   ONTARIO        CORPORATE
# 980   BOBBY ODEGARD           ONTARIO   ONTARIO        CORPORATE
# 981   BOBBY ODEGARD           ONTARIO   ONTARIO        CORPORATE
# 982   BOBBY ODEGARD           ONTARIO   ONTARIO        CORPORATE
# 983   BOBBY ODEGARD           ONTARIO   ONTARIO        CORPORATE
# 984   BOBBY ODEGARD           ONTARIO   ONTARIO        CORPORATE
# 985   BOBBY TRAFTON  BRITISH COLUMBIA      WEST        CORPORATE
# 986   BOBBY TRAFTON  BRITISH COLUMBIA      WEST        CORPORATE
# 987   BOBBY TRAFTON  BRITISH COLUMBIA      WEST        CORPORATE
# 988   BOBBY TRAFTON  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 989   BOBBY TRAFTON  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 990   BOBBY TRAFTON  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 991   BOBBY TRAFTON  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 992   BOBBY TRAFTON  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 993   BOBBY TRAFTON  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 994   BOBBY TRAFTON      NEWFOUNDLAND  ATLANTIC   SMALL BUSINESS
# 995   BOBBY TRAFTON      NEWFOUNDLAND  ATLANTIC   SMALL BUSINESS
# 996   BOBBY TRAFTON       NOVA SCOTIA  ATLANTIC        CORPORATE
# 997   BOBBY TRAFTON       NOVA SCOTIA  ATLANTIC   SMALL BUSINESS
# 998   BOBBY TRAFTON       NOVA SCOTIA  ATLANTIC   SMALL BUSINESS
# 999   BOBBY TRAFTON       NOVA SCOTIA  ATLANTIC   SMALL BUSINESS
#
# [1000 rows x 14 columns]

# %%
# Now, you can subset the orders made by customers from 'Corporate' segment
df_1.loc[df_1.Customer_Segment == 'SMALL BUSINESS', :]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 19     Ord_996  Prod_13  SHP_1378   Cust_371     41.9700      0.05
# 20     Ord_996  Prod_13  SHP_1378   Cust_371     57.1700      0.08
# 21     Ord_996   Prod_6  SHP_1378   Cust_371     81.2500      0.01
# 22     Ord_996   Prod_5  SHP_1377   Cust_371   3202.2500      0.09
# 23     Ord_996   Prod_7  SHP_1378   Cust_371     35.6400      0.05
# 24    Ord_2573   Prod_3  SHP_3525   Cust_931    197.6100      0.08
# 25    Ord_2335  Prod_13  SHP_3204   Cust_931     38.2600      0.03
# 26    Ord_2456   Prod_5  SHP_3367   Cust_931    109.5800      0.00
# 27    Ord_2405   Prod_9  SHP_3300   Cust_931   1062.6900      0.01
# 28    Ord_2573   Prod_4  SHP_3527   Cust_931   3594.7435      0.05
# 29    Ord_2478  Prod_12  SHP_3395   Cust_931    139.9800      0.07
# 30    Ord_2334   Prod_9  SHP_3203   Cust_931    129.1000      0.00
# 31    Ord_2573   Prod_7  SHP_3526   Cust_931     68.9200      0.04
# 32    Ord_2343   Prod_6  SHP_3215   Cust_931     76.1600      0.04
# 33    Ord_5046  Prod_17  SHP_7042  Cust_1710    630.9900      0.07
# 34    Ord_5040   Prod_3  SHP_7033  Cust_1710    193.8400      0.07
# 35    Ord_5033   Prod_2  SHP_7022  Cust_1710    139.0000      0.05
# 36    Ord_5029  Prod_13  SHP_7016  Cust_1710     54.7900      0.05
# 37    Ord_5040   Prod_2  SHP_7032  Cust_1710   1637.7800      0.08
# 38    Ord_5035  Prod_12  SHP_7025  Cust_1710    416.8000      0.01
# 39    Ord_5045   Prod_5  SHP_7040  Cust_1710   1286.8700      0.05
# 40    Ord_5035  Prod_15  SHP_7024  Cust_1710   4917.6900      0.02
# 41    Ord_5046   Prod_7  SHP_7041  Cust_1710    202.1100      0.08
# 42    Ord_1184  Prod_11  SHP_1635   Cust_452     73.4400      0.00
# 43    Ord_1189   Prod_6  SHP_1641   Cust_452     49.6100      0.00
# 44    Ord_1184   Prod_1  SHP_1634   Cust_452   1974.6600      0.06
# 84    Ord_5232  Prod_17  SHP_7306  Cust_1758  21366.5100      0.00
# 85    Ord_5232   Prod_6  SHP_7308  Cust_1758     88.5700      0.03
# 86    Ord_5232   Prod_6  SHP_7309  Cust_1758     73.9700      0.10
# 87    Ord_5232   Prod_6  SHP_7307  Cust_1758    320.0400      0.02
# ...        ...      ...       ...        ...         ...       ...
# 8173  Ord_2264  Prod_13  SHP_3086   Cust_889    105.4400      0.00
# 8174  Ord_1930  Prod_15  SHP_3133   Cust_889   1619.5100      0.05
# 8184  Ord_4030  Prod_13  SHP_5610  Cust_1387    124.0100      0.08
# 8185  Ord_4053   Prod_9  SHP_5649  Cust_1387    662.5100      0.09
# 8186  Ord_4030  Prod_13  SHP_5611  Cust_1387   1836.8400      0.09
# 8187  Ord_4047   Prod_5  SHP_5639  Cust_1387     30.9200      0.02
# 8188  Ord_4053  Prod_13  SHP_5650  Cust_1387     61.1800      0.00
# 8189  Ord_4093   Prod_3  SHP_5705  Cust_1387     23.1800      0.05
# 8190  Ord_4093   Prod_2  SHP_5705  Cust_1387   1290.3700      0.05
# 8191  Ord_4047   Prod_7  SHP_5640  Cust_1387    142.8000      0.01
# 8192  Ord_4021   Prod_3  SHP_5596  Cust_1387    496.1500      0.03
# 8193  Ord_4041  Prod_13  SHP_5630  Cust_1387    116.6300      0.03
# 8194   Ord_784   Prod_6  SHP_1077   Cust_233    871.3200      0.10
# 8195   Ord_687  Prod_15   SHP_941   Cust_233   1187.1200      0.06
# 8196   Ord_716   Prod_3   SHP_980   Cust_233    135.3100      0.06
# 8197   Ord_709   Prod_8   SHP_971   Cust_233    729.9200      0.00
# 8198   Ord_687   Prod_6   SHP_942   Cust_233    108.3100      0.05
# 8199   Ord_838   Prod_5  SHP_1148   Cust_273    961.0600      0.05
# 8200   Ord_838   Prod_8  SHP_1148   Cust_273   1435.9500      0.05
# 8250  Ord_5441  Prod_13  SHP_7602  Cust_1819     44.6400      0.03
# 8251  Ord_5471   Prod_8  SHP_7644  Cust_1819    214.9400      0.06
# 8252  Ord_5453   Prod_2  SHP_7622  Cust_1819    388.9000      0.10
# 8253  Ord_5487   Prod_5  SHP_7666  Cust_1819     25.8400      0.04
# 8254  Ord_5488   Prod_6  SHP_7668  Cust_1819   1767.4700      0.05
# 8255  Ord_5488   Prod_5  SHP_7670  Cust_1819   1276.7300      0.08
# 8256  Ord_5488   Prod_2  SHP_7669  Cust_1819   2164.0700      0.01
# 8257  Ord_5414   Prod_8  SHP_7559  Cust_1819   1383.2000      0.01
# 8258  Ord_5441   Prod_4  SHP_7603  Cust_1819   1289.6200      0.03
# 8259  Ord_5454  Prod_13  SHP_7623  Cust_1819    172.0100      0.06
# 8260  Ord_5470   Prod_5  SHP_7642  Cust_1819    284.0000      0.01
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin  \
# 19                12    -37.03           4.20                 0.56
# 20                18    -24.03           2.31                 0.56
# 21                11    -44.54           7.86                 0.37
# 22                44    991.26          19.99                 0.43
# 23                10     -0.71           1.63                 0.36
# 24                13      3.46           7.27                 0.38
# 25                22     -2.34           0.70                 0.56
# 26                13     31.32           4.00                 0.42
# 27                28    401.80           6.66                 0.40
# 28                38   1016.97           2.50                 0.55
# 29                33   -140.54           6.89                 0.39
# 30                27    -59.82           4.99                 0.38
# 31                22      2.63           1.58                 0.39
# 32                12    -24.03           5.20                 0.36
# 33                49   -114.64           9.44                 0.39
# 34                23   -117.10           8.94                 0.40
# 35                16    -96.33           9.23                 0.58
# 36                 9     -6.82           2.27                 0.56
# 37                38    461.65           4.62                 0.56
# 38                32    223.38           0.50                 0.38
# 39                48    384.38           6.93                 0.49
# 40                42    126.31          30.00                 0.71
# 41                40    -17.49           3.39                 0.37
# 42                 3    -53.78          27.75                 0.76
# 43                 1    -41.82          17.08                 0.40
# 44                32   -929.68          35.00                 0.80
# 84                 3 -11984.40          24.49                 0.39
# 85                12    -28.25           6.15                 0.37
# 86                13    -38.35           5.67                 0.36
# 87                34     32.47           4.39                 0.38
# ...              ...       ...            ...                  ...
# 8173              17     18.76           1.20                 0.55
# 8174              13   -722.23          70.20                 0.74
# 8184              39   -109.02           3.97                 0.56
# 8185              46    293.32           1.39                 0.38
# 8186              49    129.95           8.99                 0.59
# 8187               3     28.64           2.83                 0.37
# 8188              21      6.85           0.70                 0.56
# 8189               2    -14.88           6.19                 0.38
# 8190              10    231.16          24.49                 0.46
# 8191              24    -25.00           3.37                 0.54
# 8192              23    213.38           1.49                 0.35
# 8193              39      6.81           0.96                 0.58
# 8194              23    315.16           5.86                 0.36
# 8195              10   -127.30          30.00                 0.69
# 8196              23    -49.32           5.01                 0.39
# 8197              33     99.31           4.00                 0.60
# 8198              16    -52.77           6.86                 0.37
# 8199              28    361.82           5.02                 0.55
# 8200              36    486.90           1.99                 0.51
# 8250               7      2.08           1.20                 0.55
# 8251              12     26.75           1.99                 0.45
# 8252              37    -37.11           4.50                 0.59
# 8253               6     -4.13           4.86                 0.41
# 8254              42    331.56          17.48                 0.36
# 8255              47    357.23           8.55                 0.42
# 8256              11     59.73          55.24                 0.57
# 8257              18    -23.44          12.14                 0.67
# 8258              41    432.52           1.10                 0.55
# 8259              26     27.47           1.56                 0.52
# 8260               4    208.31          10.84                 0.63
#
#          Customer_Name          Province    Region Customer_Segment
# 19      AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 20      AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 21      AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 22      AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 23      AARON SMAYLING          MANITOBA    PRARIE   SMALL BUSINESS
# 24      AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 25      AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 26      AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 27      AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 28      AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 29      AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 30      AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 31      AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 32      AARON SMAYLING            QUEBEC    QUEBEC   SMALL BUSINESS
# 33     ADAM BELLAVANCE           ALBERTA      WEST   SMALL BUSINESS
# 34     ADAM BELLAVANCE           ALBERTA      WEST   SMALL BUSINESS
# 35     ADAM BELLAVANCE           ALBERTA      WEST   SMALL BUSINESS
# 36     ADAM BELLAVANCE           ALBERTA      WEST   SMALL BUSINESS
# 37     ADAM BELLAVANCE           ALBERTA      WEST   SMALL BUSINESS
# 38     ADAM BELLAVANCE           ALBERTA      WEST   SMALL BUSINESS
# 39     ADAM BELLAVANCE           ALBERTA      WEST   SMALL BUSINESS
# 40     ADAM BELLAVANCE           ALBERTA      WEST   SMALL BUSINESS
# 41     ADAM BELLAVANCE           ALBERTA      WEST   SMALL BUSINESS
# 42     ADAM BELLAVANCE           ONTARIO   ONTARIO   SMALL BUSINESS
# 43     ADAM BELLAVANCE           ONTARIO   ONTARIO   SMALL BUSINESS
# 44     ADAM BELLAVANCE           ONTARIO   ONTARIO   SMALL BUSINESS
# 84       ADRIAN BARTON           ALBERTA      WEST   SMALL BUSINESS
# 85       ADRIAN BARTON           ALBERTA      WEST   SMALL BUSINESS
# 86       ADRIAN BARTON           ALBERTA      WEST   SMALL BUSINESS
# 87       ADRIAN BARTON           ALBERTA      WEST   SMALL BUSINESS
# ...                ...               ...       ...              ...
# 8173      TROY STAEBEL            QUEBEC    QUEBEC   SMALL BUSINESS
# 8174      TROY STAEBEL            QUEBEC    QUEBEC   SMALL BUSINESS
# 8184       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8185       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8186       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8187       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8188       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8189       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8190       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8191       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8192       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8193       TRUDY BROWN       SASKACHEWAN    PRARIE   SMALL BUSINESS
# 8194     TRUDY SCHMIDT  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 8195     TRUDY SCHMIDT  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 8196     TRUDY SCHMIDT  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 8197     TRUDY SCHMIDT  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 8198     TRUDY SCHMIDT  BRITISH COLUMBIA      WEST   SMALL BUSINESS
# 8199     TRUDY SCHMIDT       NOVA SCOTIA  ATLANTIC   SMALL BUSINESS
# 8200     TRUDY SCHMIDT       NOVA SCOTIA  ATLANTIC   SMALL BUSINESS
# 8250  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8251  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8252  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8253  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8254  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8255  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8256  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8257  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8258  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8259  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
# 8260  VICTORIA BRENNAN           ALBERTA      WEST   SMALL BUSINESS
#
# [1642 rows x 14 columns]

# %%
# Example 2: Select all orders from product category = office supplies and from the corporate segment
# We now need to merge the product_df

df_2 = pd.merge(df_1, product_df, how='inner', on='Prod_id')
df_2.iloc[:,9:]
# Out:
#       Product_Base_Margin        Customer_Name               Province  \
# 0                    0.56        AARON BERGMAN                ALBERTA
# 1                    0.57        AARON HAWKINS                ONTARIO
# 2                    0.56         ADRIAN SHAMI                ALBERTA
# 3                    0.60  ALEKSANDRA GANNAWAY            SASKACHEWAN
# 4                    0.59         ALLEN ARMOLD          NEW BRUNSWICK
# 5                    0.57          ALYSSA TATE       BRITISH COLUMBIA
# 6                    0.57              AMY COX            NOVA SCOTIA
# 7                    0.59              AMY COX                  YUKON
# 8                    0.56             AMY HUNT            SASKACHEWAN
# 9                    0.55           ANDY YOTOV                ONTARIO
# 10                   0.59       ANEMONE RATNER                ONTARIO
# 11                   0.82        ANNA HABERLIN                ONTARIO
# 12                   0.55           ANNE PRYOR                 QUEBEC
# 13                   0.59           ART FOSTER                ONTARIO
# 14                   0.81        BARRY WEIRICH                NUNAVUT
# 15                   0.59         BART WATTERS       BRITISH COLUMBIA
# 16                   0.60         BART WATTERS       BRITISH COLUMBIA
# 17                   0.59          BEN WALLACE                 QUEBEC
# 18                   0.57      BENJAMIN FARHAT                  YUKON
# 19                   0.55      BENJAMIN FARHAT                  YUKON
# 20                   0.59        BETH FRITZLER            SASKACHEWAN
# 21                   0.56        BETH THOMPSON  NORTHWEST TERRITORIES
# 22                   0.57       BILL DONATELLI                ONTARIO
# 23                   0.59         BILL STEWART                ONTARIO
# 24                   0.56          BOBBY ELIAS       BRITISH COLUMBIA
# 25                   0.55          BRAD THOMAS                  YUKON
# 26                   0.55      CARI SCHNELLING  NORTHWEST TERRITORIES
# 27                   0.56        CARLOS MEADOR                 QUEBEC
# 28                   0.83       CARLOS SOLTERO  NORTHWEST TERRITORIES
# 29                   0.56    CASSANDRA BRANDOW                ALBERTA
# ...                   ...                  ...                    ...
# 8369                 0.37     MAXWELL SCHWARTZ            SASKACHEWAN
# 8370                 0.50     MICHELLE ELLISON                ONTARIO
# 8371                 0.40   MICHELLE HUTHWAITE                 QUEBEC
# 8372                 0.50     MITCH WILLINGHAM            SASKACHEWAN
# 8373                 0.50      MUHAMMED YEDWAB          NEW BRUNSWICK
# 8374                 0.37         NATHAN MAUTZ          NEW BRUNSWICK
# 8375                 0.41         NOEL STAAVOS            NOVA SCOTIA
# 8376                 0.52       NORA PELLETIER               MANITOBA
# 8377                 0.37       PARHENA NORRIS               MANITOBA
# 8378                 0.50      PATRICK BZOSTEK                ONTARIO
# 8379                 0.38         PAUL KNUTSON            NOVA SCOTIA
# 8380                 0.46    PHILISSE OVERCASH       BRITISH COLUMBIA
# 8381                 0.50         RAYMOND BOOK                ALBERTA
# 8382                 0.37         RAYMOND BOOK                ALBERTA
# 8383                 0.46         RESI POLKING                ALBERTA
# 8384                 0.37      RITSA HIGHTOWER                ONTARIO
# 8385                 0.41           ROY SKARIA       BRITISH COLUMBIA
# 8386                 0.50           ROY SKARIA               MANITOBA
# 8387                 0.38         RUBEN AUSMAN                ONTARIO
# 8388                 0.36         SANJIT CHAND       BRITISH COLUMBIA
# 8389                 0.41          SEAN MILLER                ONTARIO
# 8390                 0.44          SETH VERNON       BRITISH COLUMBIA
# 8391                 0.36     STEPHANIE PHELPS                ALBERTA
# 8392                 0.46         SUSAN PISTEK            SASKACHEWAN
# 8393                 0.37        TOBY CARLISLE            SASKACHEWAN
# 8394                 0.46        TONJA TURNELL                ALBERTA
# 8395                 0.37         TONY CHAPMAN       BRITISH COLUMBIA
# 8396                 0.52           TONY SAYRE                ALBERTA
# 8397                 0.37      VICTORIA WILSON                ONTARIO
# 8398                 0.50        WILLIAM BROWN            SASKACHEWAN
#
#                      Region Customer_Segment Product_Category  \
# 0                      WEST        CORPORATE  OFFICE SUPPLIES
# 1                   ONTARIO      HOME OFFICE  OFFICE SUPPLIES
# 2                      WEST         CONSUMER  OFFICE SUPPLIES
# 3                    PRARIE        CORPORATE  OFFICE SUPPLIES
# 4                  ATLANTIC      HOME OFFICE  OFFICE SUPPLIES
# 5                      WEST   SMALL BUSINESS  OFFICE SUPPLIES
# 6                  ATLANTIC   SMALL BUSINESS  OFFICE SUPPLIES
# 7                     YUKON        CORPORATE  OFFICE SUPPLIES
# 8                    PRARIE   SMALL BUSINESS  OFFICE SUPPLIES
# 9                   ONTARIO        CORPORATE  OFFICE SUPPLIES
# 10                  ONTARIO   SMALL BUSINESS  OFFICE SUPPLIES
# 11                  ONTARIO        CORPORATE  OFFICE SUPPLIES
# 12                   QUEBEC      HOME OFFICE  OFFICE SUPPLIES
# 13                  ONTARIO      HOME OFFICE  OFFICE SUPPLIES
# 14                  NUNAVUT        CORPORATE  OFFICE SUPPLIES
# 15                     WEST        CORPORATE  OFFICE SUPPLIES
# 16                     WEST        CORPORATE  OFFICE SUPPLIES
# 17                   QUEBEC      HOME OFFICE  OFFICE SUPPLIES
# 18                    YUKON      HOME OFFICE  OFFICE SUPPLIES
# 19                    YUKON      HOME OFFICE  OFFICE SUPPLIES
# 20                   PRARIE   SMALL BUSINESS  OFFICE SUPPLIES
# 21    NORTHWEST TERRITORIES        CORPORATE  OFFICE SUPPLIES
# 22                  ONTARIO        CORPORATE  OFFICE SUPPLIES
# 23                  ONTARIO        CORPORATE  OFFICE SUPPLIES
# 24                     WEST   SMALL BUSINESS  OFFICE SUPPLIES
# 25                    YUKON      HOME OFFICE  OFFICE SUPPLIES
# 26    NORTHWEST TERRITORIES   SMALL BUSINESS  OFFICE SUPPLIES
# 27                   QUEBEC        CORPORATE  OFFICE SUPPLIES
# 28    NORTHWEST TERRITORIES   SMALL BUSINESS  OFFICE SUPPLIES
# 29                     WEST      HOME OFFICE  OFFICE SUPPLIES
# ...                     ...              ...              ...
# 8369                 PRARIE        CORPORATE       TECHNOLOGY
# 8370                ONTARIO         CONSUMER       TECHNOLOGY
# 8371                 QUEBEC      HOME OFFICE       TECHNOLOGY
# 8372                 PRARIE        CORPORATE       TECHNOLOGY
# 8373               ATLANTIC         CONSUMER       TECHNOLOGY
# 8374               ATLANTIC        CORPORATE       TECHNOLOGY
# 8375               ATLANTIC      HOME OFFICE       TECHNOLOGY
# 8376                 PRARIE      HOME OFFICE       TECHNOLOGY
# 8377                 PRARIE      HOME OFFICE       TECHNOLOGY
# 8378                ONTARIO         CONSUMER       TECHNOLOGY
# 8379               ATLANTIC        CORPORATE       TECHNOLOGY
# 8380                   WEST   SMALL BUSINESS       TECHNOLOGY
# 8381                   WEST         CONSUMER       TECHNOLOGY
# 8382                   WEST         CONSUMER       TECHNOLOGY
# 8383                   WEST   SMALL BUSINESS       TECHNOLOGY
# 8384                ONTARIO        CORPORATE       TECHNOLOGY
# 8385                   WEST        CORPORATE       TECHNOLOGY
# 8386                 PRARIE        CORPORATE       TECHNOLOGY
# 8387                ONTARIO        CORPORATE       TECHNOLOGY
# 8388                   WEST      HOME OFFICE       TECHNOLOGY
# 8389                ONTARIO   SMALL BUSINESS       TECHNOLOGY
# 8390                   WEST      HOME OFFICE       TECHNOLOGY
# 8391                   WEST         CONSUMER       TECHNOLOGY
# 8392                 PRARIE      HOME OFFICE       TECHNOLOGY
# 8393                 PRARIE      HOME OFFICE       TECHNOLOGY
# 8394                   WEST         CONSUMER       TECHNOLOGY
# 8395                   WEST         CONSUMER       TECHNOLOGY
# 8396                   WEST   SMALL BUSINESS       TECHNOLOGY
# 8397                ONTARIO      HOME OFFICE       TECHNOLOGY
# 8398                 PRARIE        CORPORATE       TECHNOLOGY
#
#                Product_Sub_Category
# 0     SCISSORS, RULERS AND TRIMMERS
# 1     SCISSORS, RULERS AND TRIMMERS
# 2     SCISSORS, RULERS AND TRIMMERS
# 3     SCISSORS, RULERS AND TRIMMERS
# 4     SCISSORS, RULERS AND TRIMMERS
# 5     SCISSORS, RULERS AND TRIMMERS
# 6     SCISSORS, RULERS AND TRIMMERS
# 7     SCISSORS, RULERS AND TRIMMERS
# 8     SCISSORS, RULERS AND TRIMMERS
# 9     SCISSORS, RULERS AND TRIMMERS
# 10    SCISSORS, RULERS AND TRIMMERS
# 11    SCISSORS, RULERS AND TRIMMERS
# 12    SCISSORS, RULERS AND TRIMMERS
# 13    SCISSORS, RULERS AND TRIMMERS
# 14    SCISSORS, RULERS AND TRIMMERS
# 15    SCISSORS, RULERS AND TRIMMERS
# 16    SCISSORS, RULERS AND TRIMMERS
# 17    SCISSORS, RULERS AND TRIMMERS
# 18    SCISSORS, RULERS AND TRIMMERS
# 19    SCISSORS, RULERS AND TRIMMERS
# 20    SCISSORS, RULERS AND TRIMMERS
# 21    SCISSORS, RULERS AND TRIMMERS
# 22    SCISSORS, RULERS AND TRIMMERS
# 23    SCISSORS, RULERS AND TRIMMERS
# 24    SCISSORS, RULERS AND TRIMMERS
# 25    SCISSORS, RULERS AND TRIMMERS
# 26    SCISSORS, RULERS AND TRIMMERS
# 27    SCISSORS, RULERS AND TRIMMERS
# 28    SCISSORS, RULERS AND TRIMMERS
# 29    SCISSORS, RULERS AND TRIMMERS
# ...                             ...
# 8369                COPIERS AND FAX
# 8370                COPIERS AND FAX
# 8371                COPIERS AND FAX
# 8372                COPIERS AND FAX
# 8373                COPIERS AND FAX
# 8374                COPIERS AND FAX
# 8375                COPIERS AND FAX
# 8376                COPIERS AND FAX
# 8377                COPIERS AND FAX
# 8378                COPIERS AND FAX
# 8379                COPIERS AND FAX
# 8380                COPIERS AND FAX
# 8381                COPIERS AND FAX
# 8382                COPIERS AND FAX
# 8383                COPIERS AND FAX
# 8384                COPIERS AND FAX
# 8385                COPIERS AND FAX
# 8386                COPIERS AND FAX
# 8387                COPIERS AND FAX
# 8388                COPIERS AND FAX
# 8389                COPIERS AND FAX
# 8390                COPIERS AND FAX
# 8391                COPIERS AND FAX
# 8392                COPIERS AND FAX
# 8393                COPIERS AND FAX
# 8394                COPIERS AND FAX
# 8395                COPIERS AND FAX
# 8396                COPIERS AND FAX
# 8397                COPIERS AND FAX
# 8398                COPIERS AND FAX
#
# [8399 rows x 7 columns]

# %%
# Select all orders from product category = office supplies and from the corporate segment
df_2.loc[(df_2['Product_Category']=='OFFICE SUPPLIES') & (df_2['Customer_Segment']=='CORPORATE'),'Product_Base_Margin':]
# Out:
#       Product_Base_Margin        Customer_Name               Province  \
# 0                    0.56        AARON BERGMAN                ALBERTA
# 3                    0.60  ALEKSANDRA GANNAWAY            SASKACHEWAN
# 7                    0.59              AMY COX                  YUKON
# 9                    0.55           ANDY YOTOV                ONTARIO
# 11                   0.82        ANNA HABERLIN                ONTARIO
# 14                   0.81        BARRY WEIRICH                NUNAVUT
# 15                   0.59         BART WATTERS       BRITISH COLUMBIA
# 16                   0.60         BART WATTERS       BRITISH COLUMBIA
# 21                   0.56        BETH THOMPSON  NORTHWEST TERRITORIES
# 22                   0.57       BILL DONATELLI                ONTARIO
# 23                   0.59         BILL STEWART                ONTARIO
# 27                   0.56        CARLOS MEADOR                 QUEBEC
# 30                   0.58         CHAD SIEVERT               MANITOBA
# 31                   0.57    CHARLES MCCROSSIN  NORTHWEST TERRITORIES
# 35                   0.60          CHUCK CLARK                ALBERTA
# 36                   0.55        CINDY CHAPMAN                  YUKON
# 37                   0.83     CINDY SCHNELLING  NORTHWEST TERRITORIES
# 40                   0.56      CYNTHIA DELANEY       BRITISH COLUMBIA
# 41                   0.57      CYNTHIA DELANEY       BRITISH COLUMBIA
# 42                   0.57           DAN LAWERA                ONTARIO
# 47                   0.56       DOROTHY WARDLE  NORTHWEST TERRITORIES
# 48                   0.57          DORRIS LOVE                 QUEBEC
# 49                   0.58        DOUG BICKFORD  NORTHWEST TERRITORIES
# 55                   0.84           ERICA BERN               MANITOBA
# 58                   0.58       ERIN CREIGHTON                ONTARIO
# 61                   0.81           FRED CHUNG                 QUEBEC
# 63                   0.58        GUY ARMSTRONG               MANITOBA
# 65                   0.81        HILARY HOLDEN   PRINCE EDWARD ISLAND
# 72                   0.60      JEREMY LONSDALE  NORTHWEST TERRITORIES
# 74                   0.84           JOHN GRADY       BRITISH COLUMBIA
# ...                   ...                  ...                    ...
# 7467                 0.59         ROLAND FJELD       BRITISH COLUMBIA
# 7469                 0.83     ROSS DEVINCENTIS                 QUEBEC
# 7470                 0.57     ROSS DEVINCENTIS                 QUEBEC
# 7471                 0.60          ROY COLLINS            SASKACHEWAN
# 7472                 0.56           ROY SKARIA               MANITOBA
# 7473                 0.61         RUBEN AUSMAN                ONTARIO
# 7475                 0.85        SALLY KNUTSON            NOVA SCOTIA
# 7481                 0.81           SCOT CORAM                ONTARIO
# 7484                 0.65           SEAN WENDT               MANITOBA
# 7488                 0.56      SHAHID SHARIARI       BRITISH COLUMBIA
# 7489                 0.57         SHAUN CHANCE                ALBERTA
# 7490                 0.78         SHAUN CHANCE                ALBERTA
# 7492                 0.66      SHIRLEY DANIELS                 QUEBEC
# 7493                 0.58      SHIRLEY JACKSON                 QUEBEC
# 7496                 0.59         SONIA COOLEY                ALBERTA
# 7497                 0.78         SONIA SUNLEY       BRITISH COLUMBIA
# 7498                 0.55     SPEROS GORANITIS                 QUEBEC
# 7500                 0.59        STEVE CHAPMAN               MANITOBA
# 7507                 0.59      SUSAN VITTORINI  NORTHWEST TERRITORIES
# 7510                 0.82       TAMARA MANNING                ALBERTA
# 7513                 0.81        TANJA NORVELL               MANITOBA
# 7520                 0.59          TIM TASLIMI                  YUKON
# 7529                 0.59        TONY MOLINARI       BRITISH COLUMBIA
# 7540                 0.60    VALERIE DOMINGUEZ               MANITOBA
# 7541                 0.68    VALERIE DOMINGUEZ               MANITOBA
# 7545                 0.60     VICTORIA PISTEKA       BRITISH COLUMBIA
# 7546                 0.60     VICTORIA PISTEKA                  YUKON
# 7551                 0.71        WILLIAM BROWN            SASKACHEWAN
# 7552                 0.85         XYLONA PRICE                ONTARIO
# 7553                  NaN        YANA SORENSEN                  YUKON
#
#                      Region Customer_Segment Product_Category  \
# 0                      WEST        CORPORATE  OFFICE SUPPLIES
# 3                    PRARIE        CORPORATE  OFFICE SUPPLIES
# 7                     YUKON        CORPORATE  OFFICE SUPPLIES
# 9                   ONTARIO        CORPORATE  OFFICE SUPPLIES
# 11                  ONTARIO        CORPORATE  OFFICE SUPPLIES
# 14                  NUNAVUT        CORPORATE  OFFICE SUPPLIES
# 15                     WEST        CORPORATE  OFFICE SUPPLIES
# 16                     WEST        CORPORATE  OFFICE SUPPLIES
# 21    NORTHWEST TERRITORIES        CORPORATE  OFFICE SUPPLIES
# 22                  ONTARIO        CORPORATE  OFFICE SUPPLIES
# 23                  ONTARIO        CORPORATE  OFFICE SUPPLIES
# 27                   QUEBEC        CORPORATE  OFFICE SUPPLIES
# 30                   PRARIE        CORPORATE  OFFICE SUPPLIES
# 31    NORTHWEST TERRITORIES        CORPORATE  OFFICE SUPPLIES
# 35                     WEST        CORPORATE  OFFICE SUPPLIES
# 36                    YUKON        CORPORATE  OFFICE SUPPLIES
# 37    NORTHWEST TERRITORIES        CORPORATE  OFFICE SUPPLIES
# 40                     WEST        CORPORATE  OFFICE SUPPLIES
# 41                     WEST        CORPORATE  OFFICE SUPPLIES
# 42                  ONTARIO        CORPORATE  OFFICE SUPPLIES
# 47    NORTHWEST TERRITORIES        CORPORATE  OFFICE SUPPLIES
# 48                   QUEBEC        CORPORATE  OFFICE SUPPLIES
# 49    NORTHWEST TERRITORIES        CORPORATE  OFFICE SUPPLIES
# 55                   PRARIE        CORPORATE  OFFICE SUPPLIES
# 58                  ONTARIO        CORPORATE  OFFICE SUPPLIES
# 61                   QUEBEC        CORPORATE  OFFICE SUPPLIES
# 63                   PRARIE        CORPORATE  OFFICE SUPPLIES
# 65                 ATLANTIC        CORPORATE  OFFICE SUPPLIES
# 72    NORTHWEST TERRITORIES        CORPORATE  OFFICE SUPPLIES
# 74                     WEST        CORPORATE  OFFICE SUPPLIES
# ...                     ...              ...              ...
# 7467                   WEST        CORPORATE  OFFICE SUPPLIES
# 7469                 QUEBEC        CORPORATE  OFFICE SUPPLIES
# 7470                 QUEBEC        CORPORATE  OFFICE SUPPLIES
# 7471                 PRARIE        CORPORATE  OFFICE SUPPLIES
# 7472                 PRARIE        CORPORATE  OFFICE SUPPLIES
# 7473                ONTARIO        CORPORATE  OFFICE SUPPLIES
# 7475               ATLANTIC        CORPORATE  OFFICE SUPPLIES
# 7481                ONTARIO        CORPORATE  OFFICE SUPPLIES
# 7484                 PRARIE        CORPORATE  OFFICE SUPPLIES
# 7488                   WEST        CORPORATE  OFFICE SUPPLIES
# 7489                   WEST        CORPORATE  OFFICE SUPPLIES
# 7490                   WEST        CORPORATE  OFFICE SUPPLIES
# 7492                 QUEBEC        CORPORATE  OFFICE SUPPLIES
# 7493                 QUEBEC        CORPORATE  OFFICE SUPPLIES
# 7496                   WEST        CORPORATE  OFFICE SUPPLIES
# 7497                   WEST        CORPORATE  OFFICE SUPPLIES
# 7498                 QUEBEC        CORPORATE  OFFICE SUPPLIES
# 7500                 PRARIE        CORPORATE  OFFICE SUPPLIES
# 7507  NORTHWEST TERRITORIES        CORPORATE  OFFICE SUPPLIES
# 7510                   WEST        CORPORATE  OFFICE SUPPLIES
# 7513                 PRARIE        CORPORATE  OFFICE SUPPLIES
# 7520                  YUKON        CORPORATE  OFFICE SUPPLIES
# 7529                   WEST        CORPORATE  OFFICE SUPPLIES
# 7540                 PRARIE        CORPORATE  OFFICE SUPPLIES
# 7541                 PRARIE        CORPORATE  OFFICE SUPPLIES
# 7545                   WEST        CORPORATE  OFFICE SUPPLIES
# 7546                  YUKON        CORPORATE  OFFICE SUPPLIES
# 7551                 PRARIE        CORPORATE  OFFICE SUPPLIES
# 7552                ONTARIO        CORPORATE  OFFICE SUPPLIES
# 7553                  YUKON        CORPORATE  OFFICE SUPPLIES
#
#                Product_Sub_Category
# 0     SCISSORS, RULERS AND TRIMMERS
# 3     SCISSORS, RULERS AND TRIMMERS
# 7     SCISSORS, RULERS AND TRIMMERS
# 9     SCISSORS, RULERS AND TRIMMERS
# 11    SCISSORS, RULERS AND TRIMMERS
# 14    SCISSORS, RULERS AND TRIMMERS
# 15    SCISSORS, RULERS AND TRIMMERS
# 16    SCISSORS, RULERS AND TRIMMERS
# 21    SCISSORS, RULERS AND TRIMMERS
# 22    SCISSORS, RULERS AND TRIMMERS
# 23    SCISSORS, RULERS AND TRIMMERS
# 27    SCISSORS, RULERS AND TRIMMERS
# 30    SCISSORS, RULERS AND TRIMMERS
# 31    SCISSORS, RULERS AND TRIMMERS
# 35    SCISSORS, RULERS AND TRIMMERS
# 36    SCISSORS, RULERS AND TRIMMERS
# 37    SCISSORS, RULERS AND TRIMMERS
# 40    SCISSORS, RULERS AND TRIMMERS
# 41    SCISSORS, RULERS AND TRIMMERS
# 42    SCISSORS, RULERS AND TRIMMERS
# 47    SCISSORS, RULERS AND TRIMMERS
# 48    SCISSORS, RULERS AND TRIMMERS
# 49    SCISSORS, RULERS AND TRIMMERS
# 55    SCISSORS, RULERS AND TRIMMERS
# 58    SCISSORS, RULERS AND TRIMMERS
# 61    SCISSORS, RULERS AND TRIMMERS
# 63    SCISSORS, RULERS AND TRIMMERS
# 65    SCISSORS, RULERS AND TRIMMERS
# 72    SCISSORS, RULERS AND TRIMMERS
# 74    SCISSORS, RULERS AND TRIMMERS
# ...                             ...
# 7467         STORAGE & ORGANIZATION
# 7469         STORAGE & ORGANIZATION
# 7470         STORAGE & ORGANIZATION
# 7471         STORAGE & ORGANIZATION
# 7472         STORAGE & ORGANIZATION
# 7473         STORAGE & ORGANIZATION
# 7475         STORAGE & ORGANIZATION
# 7481         STORAGE & ORGANIZATION
# 7484         STORAGE & ORGANIZATION
# 7488         STORAGE & ORGANIZATION
# 7489         STORAGE & ORGANIZATION
# 7490         STORAGE & ORGANIZATION
# 7492         STORAGE & ORGANIZATION
# 7493         STORAGE & ORGANIZATION
# 7496         STORAGE & ORGANIZATION
# 7497         STORAGE & ORGANIZATION
# 7498         STORAGE & ORGANIZATION
# 7500         STORAGE & ORGANIZATION
# 7507         STORAGE & ORGANIZATION
# 7510         STORAGE & ORGANIZATION
# 7513         STORAGE & ORGANIZATION
# 7520         STORAGE & ORGANIZATION
# 7529         STORAGE & ORGANIZATION
# 7540         STORAGE & ORGANIZATION
# 7541         STORAGE & ORGANIZATION
# 7545         STORAGE & ORGANIZATION
# 7546         STORAGE & ORGANIZATION
# 7551         STORAGE & ORGANIZATION
# 7552         STORAGE & ORGANIZATION
# 7553         STORAGE & ORGANIZATION
#
# [1680 rows x 7 columns]

# %% [markdown]
# Similary, you can merge the other dimension tables - ```shipping_df``` and ```orders_df``` to create a ```master_df``` and perform indexing using any column in the master dataframe.

# %%
# Merging shipping_df
df_3 = pd.merge(df_2, shipping_df, how='inner', on='Ship_id')
df_3.shape
df_3
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# 5     Ord_4796  Prod_16  SHP_6686  Cust_1659     95.09      0.09
# 6     Ord_4796   Prod_6  SHP_6686  Cust_1659    122.09      0.04
# 7     Ord_1854  Prod_16  SHP_2548   Cust_727    182.47      0.05
# 8     Ord_1854   Prod_6  SHP_2548   Cust_622    817.53      0.03
# 9     Ord_1854  Prod_17  SHP_2548   Cust_564     25.96      0.06
# 10    Ord_4506  Prod_16  SHP_6273  Cust_1544     92.02      0.07
# 11    Ord_4080  Prod_16  SHP_5688  Cust_1388    666.40      0.00
# 12    Ord_1551  Prod_16  SHP_2145   Cust_531    184.77      0.00
# 13    Ord_1579  Prod_16  SHP_2178   Cust_566    139.37      0.04
# 14    Ord_1429  Prod_16  SHP_1976   Cust_510    539.06      0.05
# 15    Ord_2471  Prod_16  SHP_3386   Cust_965     90.93      0.05
# 16    Ord_2471  Prod_13  SHP_3386   Cust_965    125.95      0.00
# 17    Ord_2873  Prod_16  SHP_3957  Cust_1052    138.55      0.03
# 18    Ord_2873   Prod_2  SHP_3957  Cust_1052    451.44      0.10
# 19      Ord_43  Prod_16    SHP_56    Cust_34   9620.82      0.04
# 20     Ord_956  Prod_16  SHP_1324   Cust_346    503.17      0.01
# 21     Ord_975  Prod_16  SHP_1345   Cust_346    638.91      0.02
# 22    Ord_2385  Prod_16  SHP_3273   Cust_939    138.84      0.00
# 23    Ord_4307  Prod_16  SHP_6011  Cust_1440    395.37      0.07
# 24    Ord_4328  Prod_16  SHP_6033  Cust_1440    103.03      0.07
# 25    Ord_4031  Prod_16  SHP_5613  Cust_1391    171.50      0.02
# 26     Ord_208  Prod_16   SHP_284    Cust_67    327.15      0.04
# 27    Ord_1154  Prod_16  SHP_1590   Cust_444    483.64      0.10
# 28    Ord_1486  Prod_16  SHP_2052   Cust_513    487.50      0.05
# 29    Ord_1486   Prod_2  SHP_2052   Cust_513     97.93      0.07
# ...        ...      ...       ...        ...       ...       ...
# 8369  Ord_2425  Prod_14  SHP_3329   Cust_934  27820.34      0.08
# 8370  Ord_1096  Prod_14  SHP_1512   Cust_423   2222.61      0.02
# 8371  Ord_4842  Prod_14  SHP_6754  Cust_1672  22319.58      0.02
# 8372  Ord_2177  Prod_14  SHP_2966   Cust_789   3960.99      0.09
# 8373  Ord_5097  Prod_14  SHP_7119  Cust_1731  21046.74      0.04
# 8374  Ord_3903  Prod_14  SHP_5417  Cust_1334   3457.99      0.05
# 8375  Ord_1699  Prod_14  SHP_2353   Cust_586  10567.45      0.10
# 8376  Ord_3629  Prod_14  SHP_5026  Cust_1260  13934.53      0.10
# 8377  Ord_4166  Prod_14  SHP_5804  Cust_1401  21956.03      0.10
# 8378  Ord_3073  Prod_14  SHP_4267  Cust_1142   3550.28      0.06
# 8379  Ord_1791  Prod_14  SHP_2711   Cust_685  21717.36      0.06
# 8380  Ord_3297  Prod_14  SHP_4573  Cust_1230  13571.70      0.00
# 8381   Ord_997  Prod_14  SHP_1379   Cust_365  28761.52      0.04
# 8382  Ord_1943  Prod_14  SHP_2661   Cust_720   6813.93      0.09
# 8383   Ord_778  Prod_14  SHP_1067   Cust_262   7813.70      0.09
# 8384  Ord_5391  Prod_14  SHP_7527  Cust_1799  24233.54      0.07
# 8385  Ord_5425  Prod_14  SHP_7580  Cust_1799  27720.98      0.07
# 8386  Ord_5018  Prod_14  SHP_7001  Cust_1696   7325.63      0.04
# 8387  Ord_1265  Prod_14  SHP_1749   Cust_466  24051.49      0.07
# 8388   Ord_669  Prod_14   SHP_916   Cust_224  20872.16      0.03
# 8389  Ord_1390  Prod_14  SHP_1919   Cust_537   6933.45      0.04
# 8390   Ord_508  Prod_14   SHP_686   Cust_186  19109.61      0.10
# 8391  Ord_1767  Prod_14  SHP_2450   Cust_583  16743.76      0.00
# 8392  Ord_5401  Prod_14  SHP_7543  Cust_1801  10281.79      0.03
# 8393  Ord_3721  Prod_14  SHP_5162  Cust_1309    614.14      0.09
# 8394  Ord_4106  Prod_14  SHP_5720  Cust_1397  11829.40      0.07
# 8395   Ord_825  Prod_14  SHP_1132   Cust_247  27663.92      0.05
# 8396  Ord_5368  Prod_14  SHP_7497  Cust_1795  17279.62      0.04
# 8397  Ord_1765  Prod_14  SHP_2446   Cust_595  14647.26      0.07
# 8398  Ord_3610  Prod_14  SHP_4998  Cust_1266   1759.65      0.06
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin  \
# 0                 23    -30.51           3.60                 0.56
# 1                 27     23.12           3.37                 0.57
# 2                 35    -17.58           3.98                 0.56
# 3                 34     61.57           3.14                 0.60
# 4                 24    -78.64           6.14                 0.59
# 5                  9    -13.53           3.37                 0.57
# 6                  6    -15.20           9.54                 0.37
# 7                 17     -3.18           3.37                 0.57
# 8                 34     76.63          11.54                 0.39
# 9                  2    -29.29           6.24                 0.36
# 10                 9    -24.88           4.68                 0.59
# 11                39      2.02           7.42                 0.56
# 12                29    -71.96           5.30                 0.55
# 13                16      1.72           2.64                 0.59
# 14                42   -123.07           4.59                 0.82
# 15                43    -72.50           2.56                 0.55
# 16                10     15.73           2.36                 0.55
# 17                16      0.90           2.64                 0.59
# 18                 6    -35.19          13.99                 0.52
# 19                 6  -1759.58          24.49                 0.81
# 20                46    -10.21           4.68                 0.59
# 21                49     77.48           3.14                 0.60
# 22                15      8.75           2.64                 0.59
# 23                37     17.15           3.37                 0.57
# 24                49    -82.63           2.56                 0.55
# 25                16    -20.41           4.68                 0.59
# 26                19     47.30           3.26                 0.56
# 27                45     28.39           3.37                 0.57
# 28                46    -25.88           4.68                 0.59
# 29                14   -616.81          49.00                 0.59
# ...              ...       ...            ...                  ...
# 8369              48  11630.15          24.49                 0.37
# 8370               3    196.08          24.49                 0.41
# 8371              41   -734.31          49.00                 0.35
# 8372              20    631.33          24.49                 0.46
# 8373              29   5217.27          24.49                 0.54
# 8374               1 -11861.46          24.49                 0.37
# 8375              38   2925.37          11.64                 0.50
# 8376              50   4352.83          11.64                 0.50
# 8377              38   5903.09          24.49                 0.50
# 8378               1 -11769.17          24.49                 0.37
# 8379              32   8249.86          24.49                 0.41
# 8380              29   3825.69          24.49                 0.52
# 8381               8    285.11          24.49                 0.37
# 8382              16    358.19          49.00                 0.38
# 8383              40   2154.33          24.49                 0.46
# 8384              43   6492.67          24.49                 0.50
# 8385              46  11984.40          24.49                 0.37
# 8386              38   1899.23          24.49                 0.46
# 8387              41   9791.04          24.49                 0.37
# 8388              29  -4437.91          24.49                 0.41
# 8389              15   1200.21          49.00                 0.38
# 8390              40   -379.29          24.49                 0.36
# 8391              23   6079.63          24.49                 0.41
# 8392              20   3272.90          24.49                 0.36
# 8393               3   -735.27          24.49                 0.46
# 8394              20   3899.72          24.49                 0.37
# 8395               8   -391.92          24.49                 0.37
# 8396              40   4176.25          24.49                 0.52
# 8397              25   5485.15          24.49                 0.37
# 8398               3  -2213.75          24.49                 0.50
#
#             Customer_Name               Province                 Region  \
# 0           AARON BERGMAN                ALBERTA                   WEST
# 1           AARON HAWKINS                ONTARIO                ONTARIO
# 2            ADRIAN SHAMI                ALBERTA                   WEST
# 3     ALEKSANDRA GANNAWAY            SASKACHEWAN                 PRARIE
# 4            ALLEN ARMOLD          NEW BRUNSWICK               ATLANTIC
# 5             ALYSSA TATE       BRITISH COLUMBIA                   WEST
# 6             ALYSSA TATE       BRITISH COLUMBIA                   WEST
# 7                 AMY COX            NOVA SCOTIA               ATLANTIC
# 8                 AMY COX           NEWFOUNDLAND               ATLANTIC
# 9                 AMY COX                ONTARIO                ONTARIO
# 10                AMY COX                  YUKON                  YUKON
# 11               AMY HUNT            SASKACHEWAN                 PRARIE
# 12             ANDY YOTOV                ONTARIO                ONTARIO
# 13         ANEMONE RATNER                ONTARIO                ONTARIO
# 14          ANNA HABERLIN                ONTARIO                ONTARIO
# 15             ANNE PRYOR                 QUEBEC                 QUEBEC
# 16             ANNE PRYOR                 QUEBEC                 QUEBEC
# 17             ART FOSTER                ONTARIO                ONTARIO
# 18             ART FOSTER                ONTARIO                ONTARIO
# 19          BARRY WEIRICH                NUNAVUT                NUNAVUT
# 20           BART WATTERS       BRITISH COLUMBIA                   WEST
# 21           BART WATTERS       BRITISH COLUMBIA                   WEST
# 22            BEN WALLACE                 QUEBEC                 QUEBEC
# 23        BENJAMIN FARHAT                  YUKON                  YUKON
# 24        BENJAMIN FARHAT                  YUKON                  YUKON
# 25          BETH FRITZLER            SASKACHEWAN                 PRARIE
# 26          BETH THOMPSON  NORTHWEST TERRITORIES  NORTHWEST TERRITORIES
# 27         BILL DONATELLI                ONTARIO                ONTARIO
# 28           BILL STEWART                ONTARIO                ONTARIO
# 29           BILL STEWART                ONTARIO                ONTARIO
# ...                   ...                    ...                    ...
# 8369     LOGAN HAUSHALTER                 QUEBEC                 QUEBEC
# 8370     LYCORIS SAUNDERS                ONTARIO                ONTARIO
# 8371        MARIBETH DONA       BRITISH COLUMBIA                   WEST
# 8372       MATT COLLISTER                 QUEBEC                 QUEBEC
# 8373    MATTHEW GRINSTEIN                ALBERTA                   WEST
# 8374     MAXWELL SCHWARTZ            SASKACHEWAN                 PRARIE
# 8375     MICHELLE ELLISON                ONTARIO                ONTARIO
# 8376     MITCH WILLINGHAM            SASKACHEWAN                 PRARIE
# 8377      MUHAMMED YEDWAB          NEW BRUNSWICK               ATLANTIC
# 8378         NATHAN MAUTZ          NEW BRUNSWICK               ATLANTIC
# 8379         NOEL STAAVOS            NOVA SCOTIA               ATLANTIC
# 8380       NORA PELLETIER               MANITOBA                 PRARIE
# 8381       PARHENA NORRIS               MANITOBA                 PRARIE
# 8382         PAUL KNUTSON            NOVA SCOTIA               ATLANTIC
# 8383    PHILISSE OVERCASH       BRITISH COLUMBIA                   WEST
# 8384         RAYMOND BOOK                ALBERTA                   WEST
# 8385         RAYMOND BOOK                ALBERTA                   WEST
# 8386         RESI POLKING                ALBERTA                   WEST
# 8387      RITSA HIGHTOWER                ONTARIO                ONTARIO
# 8388           ROY SKARIA       BRITISH COLUMBIA                   WEST
# 8389         RUBEN AUSMAN                ONTARIO                ONTARIO
# 8390         SANJIT CHAND       BRITISH COLUMBIA                   WEST
# 8391          SEAN MILLER                ONTARIO                ONTARIO
# 8392     STEPHANIE PHELPS                ALBERTA                   WEST
# 8393         SUSAN PISTEK            SASKACHEWAN                 PRARIE
# 8394        TOBY CARLISLE            SASKACHEWAN                 PRARIE
# 8395         TONY CHAPMAN       BRITISH COLUMBIA                   WEST
# 8396           TONY SAYRE                ALBERTA                   WEST
# 8397      VICTORIA WILSON                ONTARIO                ONTARIO
# 8398        WILLIAM BROWN            SASKACHEWAN                 PRARIE
#
#      Customer_Segment Product_Category           Product_Sub_Category  \
# 0           CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 1         HOME OFFICE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 2            CONSUMER  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 3           CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 4         HOME OFFICE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 5      SMALL BUSINESS  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 6      SMALL BUSINESS  OFFICE SUPPLIES                          PAPER
# 7      SMALL BUSINESS  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 8      SMALL BUSINESS  OFFICE SUPPLIES                          PAPER
# 9      SMALL BUSINESS       TECHNOLOGY                OFFICE MACHINES
# 10          CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 11     SMALL BUSINESS  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 12          CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 13     SMALL BUSINESS  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 14          CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 15        HOME OFFICE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 16        HOME OFFICE  OFFICE SUPPLIES            PENS & ART SUPPLIES
# 17        HOME OFFICE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 18        HOME OFFICE  OFFICE SUPPLIES                     APPLIANCES
# 19          CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 20          CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 21          CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 22        HOME OFFICE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 23        HOME OFFICE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 24        HOME OFFICE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 25     SMALL BUSINESS  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 26          CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 27          CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 28          CORPORATE  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS
# 29          CORPORATE  OFFICE SUPPLIES                     APPLIANCES
# ...               ...              ...                            ...
# 8369        CORPORATE       TECHNOLOGY                COPIERS AND FAX
# 8370      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8371      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8372      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8373   SMALL BUSINESS       TECHNOLOGY                COPIERS AND FAX
# 8374        CORPORATE       TECHNOLOGY                COPIERS AND FAX
# 8375         CONSUMER       TECHNOLOGY                COPIERS AND FAX
# 8376        CORPORATE       TECHNOLOGY                COPIERS AND FAX
# 8377         CONSUMER       TECHNOLOGY                COPIERS AND FAX
# 8378        CORPORATE       TECHNOLOGY                COPIERS AND FAX
# 8379      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8380      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8381      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8382        CORPORATE       TECHNOLOGY                COPIERS AND FAX
# 8383   SMALL BUSINESS       TECHNOLOGY                COPIERS AND FAX
# 8384         CONSUMER       TECHNOLOGY                COPIERS AND FAX
# 8385         CONSUMER       TECHNOLOGY                COPIERS AND FAX
# 8386   SMALL BUSINESS       TECHNOLOGY                COPIERS AND FAX
# 8387        CORPORATE       TECHNOLOGY                COPIERS AND FAX
# 8388        CORPORATE       TECHNOLOGY                COPIERS AND FAX
# 8389        CORPORATE       TECHNOLOGY                COPIERS AND FAX
# 8390      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8391   SMALL BUSINESS       TECHNOLOGY                COPIERS AND FAX
# 8392         CONSUMER       TECHNOLOGY                COPIERS AND FAX
# 8393      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8394      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8395         CONSUMER       TECHNOLOGY                COPIERS AND FAX
# 8396   SMALL BUSINESS       TECHNOLOGY                COPIERS AND FAX
# 8397      HOME OFFICE       TECHNOLOGY                COPIERS AND FAX
# 8398        CORPORATE       TECHNOLOGY                COPIERS AND FAX
#
#       Order_ID       Ship_Mode   Ship_Date
# 0        36262     REGULAR AIR  28-07-2010
# 1        37863     REGULAR AIR  26-02-2011
# 2        53026     REGULAR AIR  03-03-2012
# 3        36992     EXPRESS AIR  09-12-2009
# 4        13920     REGULAR AIR  10-10-2009
# 5        55554     REGULAR AIR  17-11-2009
# 6        55554     REGULAR AIR  17-11-2009
# 7        48455     REGULAR AIR  03-06-2009
# 8        48455     REGULAR AIR  03-06-2009
# 9        48455     REGULAR AIR  03-06-2009
# 10       19524     REGULAR AIR  15-01-2010
# 11       43653     EXPRESS AIR  31-10-2012
# 12       39330     EXPRESS AIR  18-07-2010
# 13       43367     EXPRESS AIR  10-03-2010
# 14       20259     REGULAR AIR  25-05-2011
# 15       36355     REGULAR AIR  03-12-2009
# 16       36355     REGULAR AIR  03-12-2009
# 17       18595     REGULAR AIR  02-02-2009
# 18       18595     REGULAR AIR  02-02-2009
# 19        6116     REGULAR AIR  22-03-2009
# 20       34721     REGULAR AIR  02-11-2010
# 21       41671     REGULAR AIR  05-12-2012
# 22       17446     EXPRESS AIR  11-06-2009
# 23       49764     EXPRESS AIR  07-10-2010
# 24       58564     REGULAR AIR  13-11-2012
# 25       16422     REGULAR AIR  11-10-2011
# 26       33377     REGULAR AIR  01-08-2011
# 27       13345     REGULAR AIR  02-09-2012
# 28       28805     REGULAR AIR  04-04-2011
# 29       28805     REGULAR AIR  04-04-2011
# ...        ...             ...         ...
# 8369     26432     REGULAR AIR  08-01-2010
# 8370     38693     REGULAR AIR  21-06-2011
# 8371      2790  DELIVERY TRUCK  20-08-2009
# 8372     48135     EXPRESS AIR  21-04-2009
# 8373     21188     REGULAR AIR  23-09-2011
# 8374     43110     REGULAR AIR  08-02-2011
# 8375     10342     REGULAR AIR  23-11-2011
# 8376     53378     EXPRESS AIR  14-07-2012
# 8377     26629     REGULAR AIR  11-07-2009
# 8378     22917     EXPRESS AIR  04-03-2009
# 8379      1444     EXPRESS AIR  07-12-2009
# 8380     18884     REGULAR AIR  26-06-2011
# 8381     48800     REGULAR AIR  23-10-2010
# 8382     38976  DELIVERY TRUCK  26-12-2010
# 8383     27298     REGULAR AIR  23-11-2011
# 8384     13126     REGULAR AIR  20-10-2011
# 8385     29569     REGULAR AIR  04-07-2011
# 8386     54214     EXPRESS AIR  05-01-2012
# 8387     45347     EXPRESS AIR  01-10-2010
# 8388     52035     REGULAR AIR  30-11-2009
# 8389     16065  DELIVERY TRUCK  20-07-2010
# 8390      5988     EXPRESS AIR  22-11-2010
# 8391     46276     REGULAR AIR  11-12-2012
# 8392     18279     REGULAR AIR  27-02-2009
# 8393     27616     REGULAR AIR  01-08-2012
# 8394     57984     REGULAR AIR  04-10-2010
# 8395     41895     REGULAR AIR  12-01-2011
# 8396      8997     REGULAR AIR  05-07-2009
# 8397     45184     REGULAR AIR  26-06-2010
# 8398     43650     REGULAR AIR  24-03-2009
#
# [8399 rows x 19 columns]

# %%
# Merging the orders table to create a master df
master_df = pd.merge(df_3, orders_df, how='inner', on='Ord_id')
master_df.shape
master_df.iloc[:,14:].head()
# Out:
#   Product_Category           Product_Sub_Category  Order_ID_x    Ship_Mode  \
# 0  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS       36262  REGULAR AIR
# 1       TECHNOLOGY   TELEPHONES AND COMMUNICATION       36262  EXPRESS AIR
# 2  OFFICE SUPPLIES                          PAPER       36262  EXPRESS AIR
# 3  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS       37863  REGULAR AIR
# 4  OFFICE SUPPLIES  SCISSORS, RULERS AND TRIMMERS       53026  REGULAR AIR
#
#     Ship_Date  Order_ID_y  Order_Date Order_Priority
# 0  28-07-2010       36262  27-07-2010  NOT SPECIFIED
# 1  27-07-2010       36262  27-07-2010  NOT SPECIFIED
# 2  28-07-2010       36262  27-07-2010  NOT SPECIFIED
# 3  26-02-2011       37863  24-02-2011           HIGH
# 4  03-03-2012       53026  26-02-2012            LOW

# %% [markdown]
# Similary, you can perform left, right and outer merges (joins) by using the argument ```how = 'left' / 'right' / 'outer'```.

# %% [markdown]
# ### Concatenating Dataframes
#
# Concatenation is much more straightforward than merging. It is used when you have dataframes having the same columns and want to append them (pile one on top of the other), or having the same rows and want to append them side-by-side.
#
# #### Concatenating Dataframes Having the Same columns
#
# Say you have two dataframes having the same columns, like so:

# %%
# dataframes having the same columns
df1 = pd.DataFrame({'Name': ['Aman', 'Joy', 'Rashmi', 'Saif'],
                    'Age': ['34', '31', '22', '33'],
                    'Gender': ['M', 'M', 'F', 'M']}
                  )

df2 = pd.DataFrame({'Name': ['Akhil', 'Asha', 'Preeti'],
                    'Age': ['31', '22', '23'],
                    'Gender': ['M', 'F', 'F']}
                  )
df1
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M

# %%
df2
# Out:
#      Name Age Gender
# 0   Akhil  31      M
# 1    Asha  22      F
# 2  Preeti  23      F

# %%
# To concatenate them, one on top of the other, you can use pd.concat
# The first argument is a sequence (list) of dataframes
# axis = 0 indicates that we want to concat along the row axis
df8 = pd.concat([df1, df2], axis = 0)
df8
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M
# 0   Akhil  31      M
# 1    Asha  22      F
# 2  Preeti  23      F

# %%
# A useful and intuitive alternative to concat along the rows is the append() function
# It concatenates along the rows
df9 = df1.append(df2)
#df9 = df9.reset_index()
#df9.iloc[6]

# %% [markdown]
# #### Concatenating Dataframes Having the Same Rows
#
# You may also have dataframes having the same rows but different columns (and having no common columns). In this case, you may want to concat them side-by-side. For e.g.:

# %%
df1 = pd.DataFrame({'Name': ['Aman', 'Joy', 'Rashmi', 'Saif'],
                    'Age': ['34', '31', '22', '33'],
                    'Gender': ['M', 'M', 'F', 'M']}
                  )
df1
# Out:
#      Name Age Gender
# 0    Aman  34      M
# 1     Joy  31      M
# 2  Rashmi  22      F
# 3    Saif  33      M

# %%
df2 = pd.DataFrame({'School': ['RK Public', 'JSP', 'Carmel Convent', 'St. Paul'],
                    'Graduation Marks': ['84', '89', '76', '91']}
                  )
df2
# Out:
#            School Graduation Marks
# 0       RK Public               84
# 1             JSP               89
# 2  Carmel Convent               76
# 3        St. Paul               91

# %%
# To join the two dataframes, use axis = 1 to indicate joining along the columns axis
# The join is possible because the corresponding rows have the same indices
pd.concat([df1, df2], axis = 1)
# Out:
#      Name Age Gender          School Graduation Marks
# 0    Aman  34      M       RK Public               84
# 1     Joy  31      M             JSP               89
# 2  Rashmi  22      F  Carmel Convent               76
# 3    Saif  33      M        St. Paul               91

# %%
df1.append(df2)
# Out:
# c:\users\chaganti.babu\documents\python 3.5\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#    Age Gender Graduation Marks    Name          School
# 0   34      M              NaN    Aman             NaN
# 1   31      M              NaN     Joy             NaN
# 2   22      F              NaN  Rashmi             NaN
# 3   33      M              NaN    Saif             NaN
# 0  NaN    NaN               84     NaN       RK Public
# 1  NaN    NaN               89     NaN             JSP
# 2  NaN    NaN               76     NaN  Carmel Convent
# 3  NaN    NaN               91     NaN        St. Paul

# %% [markdown]
# Note that you can also use the ```pd.concat()``` method to merge dataframes using common keys, though here we will not discuss that. For simplicity, we have used the ```pd.merge()``` method for database-style merging and ```pd.concat()``` for appending dataframes having no common columns.
